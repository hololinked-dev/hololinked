# %%
import importlib
import os
import sys

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../")))

from pprint import pprint
import threading 
import asyncio
import ssl

import hololinked
import things 

importlib.reload(hololinked)
importlib.reload(things)

from hololinked.core import Thing
from hololinked.constants import Operations


from things import OceanOpticsSpectrometer, TestThing

# %%
thing = TestThing(id='example-test')
thing.run(
    access_points=[
        ("ZMQ", ["tcp://*:5558", "IPC"]),
        ("HTTP", 8080),
    ],
    forked=True
)
# thing.run_with_zmq_server(['IPC', 'TCP'], forked=True)
# thing.run_with_http_server(forked=True)
# Out:
# INFO     - 2025-10-04T16:54:24:934 - example-test - initialialised Thing class TestThing with id example-test
# INFO     - 2025-10-04T16:54:24:938 - example-test - created socket type: ROUTER with address: inproc://example-test & identity: example-test and bound
# INFO     - 2025-10-04T16:54:24:942 - example-test - created socket type: PUB with address: inproc://example-test/event-publisher & identity: example-test/event-publisher and bound
# <Thread(Thread-7 (run), started daemon 3140)>
# INFO     - 2025-10-04T16:54:24:944 - example-test - created socket type: ROUTER with address: tcp://*:5558 & identity: example-test and bound
# INFO     - 2025-10-04T16:54:24:946 - example-test - created socket type: PUB with address: tcp://*:5559 & identity: example-test/event-publisher and bound
# INFO     - 2025-10-04T16:54:24:950 - example-test - created socket type: ROUTER with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test.ipc & identity: example-test and bound
# INFO     - 2025-10-04T16:54:24:955 - example-test - created socket type: PUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test/event-publisher and bound
# INFO     - 2025-10-04T16:54:24:957 - example-test - created socket type: SUB with address: inproc://example-test/event-publisher & identity: example-test/event-proxy and connected
# INFO     - 2025-10-04T16:54:24:960 - example-test - starting RPC server example-test
# INFO     - 2025-10-04T16:54:24:962 - example-test - starting thing executor loop in thread 5956 for ['example-test']
# INFO     - 2025-10-04T16:54:24:965 - example-test - starting to run operations on thing example-test of class TestThing
# INFO     - 2025-10-04T16:54:24:965 - example-test - starting external message listener thread
# INFO     - 2025-10-04T16:54:25:132 - HTTPServer|0.0.0.0:8080 - created socket type: ROUTER with address: inproc://example-test & identity: 0.0.0.0:8080 and connected
# INFO     - 2025-10-04T16:54:25:136 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-10-04T16:54:25:138 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-10-04T16:54:25:138 - HTTPServer|0.0.0.0:8080 - client '0.0.0.0:8080' handshook with server 'example-test'
# payload before deserialize SerializableData(value=b'{"ignore_errors":true,"protocol":"INPROC"}', serializer=None, content_type='application/json', _serialized=None)
# ERROR    - 2025-10-04T16:54:25:143 - example-test - Error while generating schema for base_property - WoT schema generator for this descriptor/property is not implemented. name base_property & type <class 'hololinked.core.property.Property'>
# INFO     - 2025-10-04T16:54:25:160 - HTTPServer|0.0.0.0:8080 - started webserver at 0.0.0.0:8080, ready to receive requests.
# INFO     - 2025-10-04T16:54:25:160 - HTTPServer|0.0.0.0:8080 - client polling started for sockets for ['0.0.0.0:8080']

# %%
pprint(thing.get_thing_model(ignore_errors=True).json(), indent=4)
# Out:
# ERROR    - 2025-09-06T19:14:17:728 - example-test - Error while generating schema for base_property - WoT schema generator for this descriptor/property is not implemented. name base_property & type <class 'hololinked.core.property.Property'>
# {   'actions': {   'action_echo': {'synchronous': True},
#                    'execute_instruction': {   'description': 'executes '
#                                                              'instruction '
#                                                              'given by the '
#                                                              'ASCII string '
#                                                              'parameter '
#                                                              "'command'. If "
#                                                              'return data size '
#                                                              'is greater than '
#                                                              '0, it reads the '
#                                                              'response and '
#                                                              'returns the '
#                                                              'response. Return '
#                                                              'Data Size - in '
#                                                              'bytes - 1 ASCII '
#                                                              'character = 1 '
#                                                              'Byte.',
#                                               'input': {   'properties': {   'command': {   'type': 'string'},
#                                                                              'return_data_size': {   'default': 0,
#                                                                                                      'minimum': 0,
#                                                                                                      'type': 'integer'}},
#                                                            'required': [   'command'],
#                                                            'type': 'object'},
#                                               'output': {'type': 'string'},
#                                               'synchronous': True},
#                    'exit': {   'description': 'Stop serving the object. This '
#                                               'method can only be called '
#                                               'remotely',
#                                'synchronous': True},
#                    'get_analogue_offset': {   'description': 'analogue offset '
#                                                              'for a voltage '
#                                                              'range and '
#                                                              'coupling',
#                                               'input': {   'properties': {   'coupling': {   'enum': [   'AC',
#                                                                                                          'DC'],
#                                                                                              'type': 'string'},
#                                                                              'voltage_range': {   'enum': [   '10mV',
#                                                                                                               '20mV',
#                                                                                                               '50mV',
#                                                                                                               '100mV',
#                                                                                                               '200mV',
#                                                                                                               '500mV',
#                                                                                                               '1V',
#                                                                                                               '2V',
#                                                                                                               '5V',
#                                                                                                               '10V',
#                                                                                                               '20V',
#                                                                                                               '50V',
#                                                                                                               'MAX_RANGES'],
#                                                                                                   'type': 'string'}},
#                                                            'type': 'object'},
#                                               'output': {   'items': {   'type': 'number'},
#                                                             'maxItems': 2,
#                                                             'minItems': 2,
#                                                             'type': 'array'},
#                                               'synchronous': True},
#                    'get_mixed_content_data': {'synchronous': True},
#                    'get_non_remote_number_prop': {'synchronous': True},
#                    'get_serialized_data': {'synchronous': True},
#                    'get_thing_model': {   'description': 'generate the [Thing '
#                                                          'Model](https://www.w3.org/TR/wot-thing-description11/#introduction-tm) '
#                                                          'of the object. The '
#                                                          'model is a JSON that '
#                                                          'describes the '
#                                                          "object's properties, "
#                                                          'actions, events and '
#                                                          'their metadata, '
#                                                          'without the protocol '
#                                                          'information. The '
#                                                          'model can be used by '
#                                                          'a client to '
#                                                          'understand the '
#                                                          "object's "
#                                                          'capabilities.',
#                                           'input': {   'properties': {   'ignore_errors': {   'default': False,
#                                                                                               'type': 'boolean'},
#                                                                          'skip_names': {   'default': [   ],
#                                                                                            'items': {   'type': 'string'},
#                                                                                            'type': 'array'}},
#                                                        'type': 'object'},
#                                           'synchronous': True},
#                    'get_transports': {'synchronous': True},
#                    'ping': {   'description': 'ping the `Thing` to see if it '
#                                               'is alive. Ping successful when '
#                                               'action succeeds with no return '
#                                               'value and no timeout or '
#                                               'exception raised on the client '
#                                               'side.',
#                                'synchronous': True},
#                    'print_props': {'synchronous': True},
#                    'push_events': {   'input': {   'properties': {   'event_name': {   'default': 'test_event',
#                                                                                        'type': 'string'},
#                                                                      'total_number_of_events': {   'default': 100,
#                                                                                                    'type': 'integer'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel': {   'description': 'Set the parameter for a '
#                                                      'channel. '
#                                                      'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                       'input': {   'properties': {   'bw_limiter': {   'enum': [   'full',
#                                                                                                    '20MHz'],
#                                                                                        'type': 'string'},
#                                                                      'channel': {   'enum': [   'A',
#                                                                                                 'B',
#                                                                                                 'C',
#                                                                                                 'D'],
#                                                                                     'type': 'string'},
#                                                                      'coupling': {   'enum': [   'AC',
#                                                                                                  'DC'],
#                                                                                      'type': 'string'},
#                                                                      'enabled': {   'type': 'boolean'},
#                                                                      'offset': {   'type': 'number'},
#                                                                      'voltage_range': {   'enum': [   '10mV',
#                                                                                                       '20mV',
#                                                                                                       '50mV',
#                                                                                                       '100mV',
#                                                                                                       '200mV',
#                                                                                                       '500mV',
#                                                                                                       '1V',
#                                                                                                       '2V',
#                                                                                                       '5V',
#                                                                                                       '10V',
#                                                                                                       '20V',
#                                                                                                       '50V',
#                                                                                                       'MAX_RANGES'],
#                                                                                           'type': 'string'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel_pydantic': {   'description': 'Set the '
#                                                               'parameter for a '
#                                                               'channel. '
#                                                               'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                                'input': {   'properties': {   'bw_limiter': {   'default': 'full',
#                                                                                                 'enum': [   'full',
#                                                                                                             '20MHz'],
#                                                                                                 'type': 'string'},
#                                                                               'channel': {   'enum': [   'A',
#                                                                                                          'B',
#                                                                                                          'C',
#                                                                                                          'D'],
#                                                                                              'type': 'string'},
#                                                                               'coupling': {   'default': 'DC_1M',
#                                                                                               'enum': [   'AC',
#                                                                                                           'DC'],
#                                                                                               'type': 'string'},
#                                                                               'enabled': {   'default': True,
#                                                                                              'type': 'boolean'},
#                                                                               'offset': {   'default': 0,
#                                                                                             'type': 'number'},
#                                                                               'v_range': {   'default': '2V',
#                                                                                              'enum': [   '10mV',
#                                                                                                          '20mV',
#                                                                                                          '50mV',
#                                                                                                          '100mV',
#                                                                                                          '200mV',
#                                                                                                          '500mV',
#                                                                                                          '1V',
#                                                                                                          '2V',
#                                                                                                          '5V',
#                                                                                                          '10V',
#                                                                                                          '20V',
#                                                                                                          '50V',
#                                                                                                          'MAX_RANGES'],
#                                                                                              'type': 'string'}},
#                                                             'required': [   'channel'],
#                                                             'type': 'object'},
#                                                'synchronous': True},
#                    'set_non_remote_number_prop': {'synchronous': True},
#                    'set_sensor_model': {   'description': 'Set the attached '
#                                                           'sensor to the meter '
#                                                           'under control. '
#                                                           'Sensor should be '
#                                                           'defined as a class '
#                                                           'and added to the '
#                                                           'AllowedSensors '
#                                                           'dict.',
#                                            'input': {   'enum': [   'QE25LP-S-MB',
#                                                                     'QE12LP-S-MB-QED-D0'],
#                                                         'type': 'string'},
#                                            'synchronous': True},
#                    'set_sensor_model_pydantic': {   'description': 'Set the '
#                                                                    'attached '
#                                                                    'sensor to '
#                                                                    'the meter '
#                                                                    'under '
#                                                                    'control. '
#                                                                    'Sensor '
#                                                                    'should be '
#                                                                    'defined as '
#                                                                    'a class '
#                                                                    'and added '
#                                                                    'to the '
#                                                                    'AllowedSensors '
#                                                                    'dict.',
#                                                     'input': {   'properties': {   'value': {   'enum': [   'QE25LP-S-MB',
#                                                                                                             'QE12LP-S-MB-QED-D0'],
#                                                                                                 'type': 'string'}},
#                                                                  'required': [   'value'],
#                                                                  'type': 'object'},
#                                                     'synchronous': True},
#                    'sleep': {'synchronous': True},
#                    'start_acquisition': {   'description': 'Start acquisition '
#                                                            'of energy '
#                                                            'measurements.',
#                                             'input': {   'properties': {   'max_count': {   'exclusiveMinimum': 0,
#                                                                                             'type': 'integer'}},
#                                                          'required': [   'max_count'],
#                                                          'type': 'object'},
#                                             'synchronous': True}},
#     'context': ['https://www.w3.org/2022/wot/td/v1.1'],
#     'events': {   'data_point_event': {   'data': {   'properties': {   'energy': {   'type': 'number'},
#                                                                         'timestamp': {   'type': 'string'}},
#                                                       'required': [   'timestamp',
#                                                                       'energy'],
#                                                       'type': 'object'},
#                                           'description': 'Event raised when a '
#                                                          'new data point is '
#                                                          'available'},
#                   'test_binary_payload_event': {   'description': 'test event '
#                                                                   'with binary '
#                                                                   'payload'},
#                   'test_event': {   'description': 'test event with arbitrary '
#                                                    'payload'},
#                   'test_event_with_json_schema': {   'description': 'test '
#                                                                     'event '
#                                                                     'with '
#                                                                     'schema '
#                                                                     'validation'},
#                   'test_event_with_pydantic_schema': {   'description': 'test '
#                                                                         'event '
#                                                                         'with '
#                                                                         'pydantic '
#                                                                         'schema '
#                                                                         'validation'},
#                   'test_mixed_content_payload_event': {   'description': 'test '
#                                                                          'event '
#                                                                          'with '
#                                                                          'mixed '
#                                                                          'content '
#                                                                          'payload'}},
#     'id': 'example-test',
#     'properties': {   'db_commit_number_prop': {   'default': 0,
#                                                    'description': 'A fully '
#                                                                   'editable '
#                                                                   'number '
#                                                                   'property to '
#                                                                   'check '
#                                                                   'commits to '
#                                                                   'db on write '
#                                                                   'operations',
#                                                    'type': 'number'},
#                       'db_init_int_prop': {   'default': 1,
#                                               'description': 'An integer '
#                                                              'property to '
#                                                              'check '
#                                                              'initialization '
#                                                              'from db',
#                                               'type': 'integer'},
#                       'db_persist_selector_prop': {   'default': 'a',
#                                                       'description': 'A '
#                                                                      'selector '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'persistence '
#                                                                      'to db on '
#                                                                      'write '
#                                                                      'operations',
#                                                       'enum': [   'a',
#                                                                   'b',
#                                                                   'c',
#                                                                   1],
#                                                       'oneOf': [   {   'type': 'string'},
#                                                                    {   'type': 'integer'}]},
#                       'deletable_class_prop': {   'default': 100,
#                                                   'description': 'deletable '
#                                                                  'class '
#                                                                  'property '
#                                                                  'with custom '
#                                                                  'deleter',
#                                                   'type': 'number'},
#                       'int_prop': {   'default': 5,
#                                       'description': 'An integer property with '
#                                                      'step and bounds '
#                                                      'constraints to check RW',
#                                       'maximum': 100,
#                                       'minimum': 0,
#                                       'multipleOf': 2,
#                                       'type': 'integer'},
#                       'json_schema_prop': {   'description': 'A property with '
#                                                              'a json schema to '
#                                                              'check RW',
#                                               'oneOf': [   {'type': 'null'},
#                                                            {   'maxLength': 10,
#                                                                'minLength': 1,
#                                                                'pattern': '^[a-z]+$',
#                                                                'type': 'string'}]},
#                       'managed_class_prop': {   'default': 0.0,
#                                                 'description': '(managed) '
#                                                                'class property '
#                                                                'with custom '
#                                                                'getter/setter',
#                                                 'type': 'number'},
#                       'not_a_class_prop': {   'default': 43,
#                                               'description': 'test property '
#                                                              'with '
#                                                              'class_member=False',
#                                               'type': 'number'},
#                       'number_prop': {   'default': 1,
#                                          'description': 'A fully editable '
#                                                         'number property',
#                                          'type': 'number'},
#                       'observable_list_prop': {   'description': 'An '
#                                                                  'observable '
#                                                                  'list '
#                                                                  'property to '
#                                                                  'check '
#                                                                  'observable '
#                                                                  'events on '
#                                                                  'write '
#                                                                  'operations',
#                                                   'observable': True,
#                                                   'oneOf': [   {   'type': 'array'},
#                                                                {   'type': 'null'}]},
#                       'observable_readonly_prop': {   'default': 0,
#                                                       'description': 'An '
#                                                                      'observable '
#                                                                      'readonly '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'observable '
#                                                                      'events '
#                                                                      'on read '
#                                                                      'operations',
#                                                       'observable': True,
#                                                       'readOnly': True,
#                                                       'type': 'number'},
#                       'pydantic_prop': {   'description': 'A property with a '
#                                                           'pydantic model to '
#                                                           'check RW',
#                                            'oneOf': [   {'type': 'null'},
#                                                         {   'properties': {   'bar': {   'type': 'integer'},
#                                                                               'foo': {   'type': 'string'},
#                                                                               'foo_bar': {   'type': 'number'}},
#                                                             'required': [   'foo',
#                                                                             'bar',
#                                                                             'foo_bar'],
#                                                             'type': 'object'}]},
#                       'pydantic_simple_prop': {   'description': 'A property '
#                                                                  'with a '
#                                                                  'simple '
#                                                                  'pydantic '
#                                                                  'model to '
#                                                                  'check RW',
#                                                   'oneOf': [   {'type': 'null'},
#                                                                {   'type': 'integer'}]},
#                       'readonly_class_prop': {   'default': '',
#                                                  'description': 'read-only '
#                                                                 'class '
#                                                                 'property',
#                                                  'readOnly': True,
#                                                  'type': 'string'},
#                       'selector_prop': {   'default': 'a',
#                                            'description': 'A selector property '
#                                                           'to check RW',
#                                            'enum': ['a', 'b', 'c', 1],
#                                            'oneOf': [   {'type': 'string'},
#                                                         {'type': 'integer'}]},
#                       'simple_class_prop': {   'default': 42,
#                                                'description': 'simple class '
#                                                               'property with '
#                                                               'default value',
#                                                'type': 'number'},
#                       'sleeping_prop': {   'default': 0,
#                                            'description': 'A property that '
#                                                           'sleeps for 10 '
#                                                           'seconds on read '
#                                                           'operations',
#                                            'observable': True,
#                                            'readOnly': True,
#                                            'type': 'number'},
#                       'string_prop': {   'default': 'hello',
#                                          'description': 'A string property '
#                                                         'with a regex '
#                                                         'constraint to check '
#                                                         'value errors',
#                                          'pattern': '^[a-z]+',
#                                          'type': 'string'},
#                       'total_number_of_events': {   'default': 100,
#                                                     'description': 'Total '
#                                                                    'number of '
#                                                                    'events '
#                                                                    'pushed',
#                                                     'minimum': 1,
#                                                     'type': 'number'}},
#     'title': 'TestThing'}

# %%
from pprint import pprint
pprint(thing.rpc_server.get_thing_description(thing, protocol='INPROC', ignore_errors=True), indent=4)
# Out:
# ERROR    - 2025-09-06T18:59:26:294 - example-test - Error while generating schema for base_property - WoT schema generator for this descriptor/property is not implemented. name base_property & type <class 'hololinked.core.property.Property'>
# {   'actions': {   'action_echo': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'invokeaction'}],
#                                       'synchronous': True},
#                    'execute_instruction': {   'description': 'executes '
#                                                              'instruction '
#                                                              'given by the '
#                                                              'ASCII string '
#                                                              'parameter '
#                                                              "'command'. If "
#                                                              'return data size '
#                                                              'is greater than '
#                                                              '0, it reads the '
#                                                              'response and '
#                                                              'returns the '
#                                                              'response. Return '
#                                                              'Data Size - in '
#                                                              'bytes - 1 ASCII '
#                                                              'character = 1 '
#                                                              'Byte.',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'invokeaction'}],
#                                               'input': {   'properties': {   'command': {   'type': 'string'},
#                                                                              'return_data_size': {   'default': 0,
#                                                                                                      'minimum': 0,
#                                                                                                      'type': 'integer'}},
#                                                            'required': [   'command'],
#                                                            'type': 'object'},
#                                               'output': {'type': 'string'},
#                                               'synchronous': True},
#                    'exit': {   'description': 'Stop serving the object. This '
#                                               'method can only be called '
#                                               'remotely',
#                                'forms': [   {   'contentType': 'application/json',
#                                                 'href': 'inproc://example-test',
#                                                 'op': 'invokeaction'}],
#                                'synchronous': True},
#                    'get_analogue_offset': {   'description': 'analogue offset '
#                                                              'for a voltage '
#                                                              'range and '
#                                                              'coupling',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'invokeaction'}],
#                                               'input': {   'properties': {   'coupling': {   'enum': [   'AC',
#                                                                                                          'DC'],
#                                                                                              'type': 'string'},
#                                                                              'voltage_range': {   'enum': [   '10mV',
#                                                                                                               '20mV',
#                                                                                                               '50mV',
#                                                                                                               '100mV',
#                                                                                                               '200mV',
#                                                                                                               '500mV',
#                                                                                                               '1V',
#                                                                                                               '2V',
#                                                                                                               '5V',
#                                                                                                               '10V',
#                                                                                                               '20V',
#                                                                                                               '50V',
#                                                                                                               'MAX_RANGES'],
#                                                                                                   'type': 'string'}},
#                                                            'type': 'object'},
#                                               'output': {   'items': {   'type': 'number'},
#                                                             'maxItems': 2,
#                                                             'minItems': 2,
#                                                             'type': 'array'},
#                                               'synchronous': True},
#                    'get_mixed_content_data': {   'forms': [   {   'contentType': 'application/json',
#                                                                   'href': 'inproc://example-test',
#                                                                   'op': 'invokeaction'}],
#                                                  'synchronous': True},
#                    'get_non_remote_number_prop': {   'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'inproc://example-test',
#                                                                       'op': 'invokeaction'}],
#                                                      'synchronous': True},
#                    'get_serialized_data': {   'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'invokeaction'}],
#                                               'synchronous': True},
#                    'get_thing_model': {   'description': 'generate the [Thing '
#                                                          'Model](https://www.w3.org/TR/wot-thing-description11/#introduction-tm) '
#                                                          'of the object. The '
#                                                          'model is a JSON that '
#                                                          'describes the '
#                                                          "object's properties, "
#                                                          'actions, events and '
#                                                          'their metadata, '
#                                                          'without the protocol '
#                                                          'information. The '
#                                                          'model can be used by '
#                                                          'a client to '
#                                                          'understand the '
#                                                          "object's "
#                                                          'capabilities.',
#                                           'forms': [   {   'contentType': 'application/json',
#                                                            'href': 'inproc://example-test',
#                                                            'op': 'invokeaction'}],
#                                           'input': {   'properties': {   'ignore_errors': {   'default': False,
#                                                                                               'type': 'boolean'},
#                                                                          'skip_names': {   'default': [   ],
#                                                                                            'items': {   'type': 'string'},
#                                                                                            'type': 'array'}},
#                                                        'type': 'object'},
#                                           'synchronous': True},
#                    'get_transports': {   'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'invokeaction'}],
#                                          'synchronous': True},
#                    'ping': {   'description': 'ping the `Thing` to see if it '
#                                               'is alive. Ping successful when '
#                                               'action succeeds with no return '
#                                               'value and no timeout or '
#                                               'exception raised on the client '
#                                               'side.',
#                                'forms': [   {   'contentType': 'application/json',
#                                                 'href': 'inproc://example-test',
#                                                 'op': 'invokeaction'}],
#                                'synchronous': True},
#                    'print_props': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'invokeaction'}],
#                                       'synchronous': True},
#                    'push_events': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'invokeaction'}],
#                                       'input': {   'properties': {   'event_name': {   'default': 'test_event',
#                                                                                        'type': 'string'},
#                                                                      'total_number_of_events': {   'default': 100,
#                                                                                                    'type': 'integer'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel': {   'description': 'Set the parameter for a '
#                                                      'channel. '
#                                                      'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                       'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'invokeaction'}],
#                                       'input': {   'properties': {   'bw_limiter': {   'enum': [   'full',
#                                                                                                    '20MHz'],
#                                                                                        'type': 'string'},
#                                                                      'channel': {   'enum': [   'A',
#                                                                                                 'B',
#                                                                                                 'C',
#                                                                                                 'D'],
#                                                                                     'type': 'string'},
#                                                                      'coupling': {   'enum': [   'AC',
#                                                                                                  'DC'],
#                                                                                      'type': 'string'},
#                                                                      'enabled': {   'type': 'boolean'},
#                                                                      'offset': {   'type': 'number'},
#                                                                      'voltage_range': {   'enum': [   '10mV',
#                                                                                                       '20mV',
#                                                                                                       '50mV',
#                                                                                                       '100mV',
#                                                                                                       '200mV',
#                                                                                                       '500mV',
#                                                                                                       '1V',
#                                                                                                       '2V',
#                                                                                                       '5V',
#                                                                                                       '10V',
#                                                                                                       '20V',
#                                                                                                       '50V',
#                                                                                                       'MAX_RANGES'],
#                                                                                           'type': 'string'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel_pydantic': {   'description': 'Set the '
#                                                               'parameter for a '
#                                                               'channel. '
#                                                               'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                                'forms': [   {   'contentType': 'application/json',
#                                                                 'href': 'inproc://example-test',
#                                                                 'op': 'invokeaction'}],
#                                                'input': {   'properties': {   'bw_limiter': {   'default': 'full',
#                                                                                                 'enum': [   'full',
#                                                                                                             '20MHz'],
#                                                                                                 'type': 'string'},
#                                                                               'channel': {   'enum': [   'A',
#                                                                                                          'B',
#                                                                                                          'C',
#                                                                                                          'D'],
#                                                                                              'type': 'string'},
#                                                                               'coupling': {   'default': 'DC_1M',
#                                                                                               'enum': [   'AC',
#                                                                                                           'DC'],
#                                                                                               'type': 'string'},
#                                                                               'enabled': {   'default': True,
#                                                                                              'type': 'boolean'},
#                                                                               'offset': {   'default': 0,
#                                                                                             'type': 'number'},
#                                                                               'v_range': {   'default': '2V',
#                                                                                              'enum': [   '10mV',
#                                                                                                          '20mV',
#                                                                                                          '50mV',
#                                                                                                          '100mV',
#                                                                                                          '200mV',
#                                                                                                          '500mV',
#                                                                                                          '1V',
#                                                                                                          '2V',
#                                                                                                          '5V',
#                                                                                                          '10V',
#                                                                                                          '20V',
#                                                                                                          '50V',
#                                                                                                          'MAX_RANGES'],
#                                                                                              'type': 'string'}},
#                                                             'required': [   'channel'],
#                                                             'type': 'object'},
#                                                'synchronous': True},
#                    'set_non_remote_number_prop': {   'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'inproc://example-test',
#                                                                       'op': 'invokeaction'}],
#                                                      'synchronous': True},
#                    'set_sensor_model': {   'description': 'Set the attached '
#                                                           'sensor to the meter '
#                                                           'under control. '
#                                                           'Sensor should be '
#                                                           'defined as a class '
#                                                           'and added to the '
#                                                           'AllowedSensors '
#                                                           'dict.',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'invokeaction'}],
#                                            'input': {   'enum': [   'QE25LP-S-MB',
#                                                                     'QE12LP-S-MB-QED-D0'],
#                                                         'type': 'string'},
#                                            'synchronous': True},
#                    'set_sensor_model_pydantic': {   'description': 'Set the '
#                                                                    'attached '
#                                                                    'sensor to '
#                                                                    'the meter '
#                                                                    'under '
#                                                                    'control. '
#                                                                    'Sensor '
#                                                                    'should be '
#                                                                    'defined as '
#                                                                    'a class '
#                                                                    'and added '
#                                                                    'to the '
#                                                                    'AllowedSensors '
#                                                                    'dict.',
#                                                     'forms': [   {   'contentType': 'application/json',
#                                                                      'href': 'inproc://example-test',
#                                                                      'op': 'invokeaction'}],
#                                                     'input': {   'properties': {   'value': {   'enum': [   'QE25LP-S-MB',
#                                                                                                             'QE12LP-S-MB-QED-D0'],
#                                                                                                 'type': 'string'}},
#                                                                  'required': [   'value'],
#                                                                  'type': 'object'},
#                                                     'synchronous': True},
#                    'sleep': {   'forms': [   {   'contentType': 'application/json',
#                                                  'href': 'inproc://example-test',
#                                                  'op': 'invokeaction'}],
#                                 'synchronous': True},
#                    'start_acquisition': {   'description': 'Start acquisition '
#                                                            'of energy '
#                                                            'measurements.',
#                                             'forms': [   {   'contentType': 'application/json',
#                                                              'href': 'inproc://example-test',
#                                                              'op': 'invokeaction'}],
#                                             'input': {   'properties': {   'max_count': {   'exclusiveMinimum': 0,
#                                                                                             'type': 'integer'}},
#                                                          'required': [   'max_count'],
#                                                          'type': 'object'},
#                                             'synchronous': True}},
#     'context': ['https://www.w3.org/2022/wot/td/v1.1'],
#     'events': {   'data_point_event': {   'data': {   'properties': {   'energy': {   'type': 'number'},
#                                                                         'timestamp': {   'type': 'string'}},
#                                                       'required': [   'timestamp',
#                                                                       'energy'],
#                                                       'type': 'object'},
#                                           'description': 'Event raised when a '
#                                                          'new data point is '
#                                                          'available',
#                                           'forms': [   {   'contentType': 'application/json',
#                                                            'href': 'inproc://example-test/event-publisher',
#                                                            'op': 'subscribeevent'}]},
#                   'test_binary_payload_event': {   'description': 'test event '
#                                                                   'with binary '
#                                                                   'payload',
#                                                    'forms': [   {   'contentType': 'application/json',
#                                                                     'href': 'inproc://example-test/event-publisher',
#                                                                     'op': 'subscribeevent'}]},
#                   'test_event': {   'description': 'test event with arbitrary '
#                                                    'payload',
#                                     'forms': [   {   'contentType': 'application/json',
#                                                      'href': 'inproc://example-test/event-publisher',
#                                                      'op': 'subscribeevent'}]},
#                   'test_event_with_json_schema': {   'description': 'test '
#                                                                     'event '
#                                                                     'with '
#                                                                     'schema '
#                                                                     'validation',
#                                                      'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'inproc://example-test/event-publisher',
#                                                                       'op': 'subscribeevent'}]},
#                   'test_event_with_pydantic_schema': {   'description': 'test '
#                                                                         'event '
#                                                                         'with '
#                                                                         'pydantic '
#                                                                         'schema '
#                                                                         'validation',
#                                                          'forms': [   {   'contentType': 'application/json',
#                                                                           'href': 'inproc://example-test/event-publisher',
#                                                                           'op': 'subscribeevent'}]},
#                   'test_mixed_content_payload_event': {   'description': 'test '
#                                                                          'event '
#                                                                          'with '
#                                                                          'mixed '
#                                                                          'content '
#                                                                          'payload',
#                                                           'forms': [   {   'contentType': 'application/json',
#                                                                            'href': 'inproc://example-test/event-publisher',
#                                                                            'op': 'subscribeevent'}]}},
#     'id': 'example-test',
#     'properties': {   'db_commit_number_prop': {   'default': 0,
#                                                    'description': 'A fully '
#                                                                   'editable '
#                                                                   'number '
#                                                                   'property to '
#                                                                   'check '
#                                                                   'commits to '
#                                                                   'db on write '
#                                                                   'operations',
#                                                    'forms': [   {   'contentType': 'application/json',
#                                                                     'href': 'inproc://example-test',
#                                                                     'op': 'readproperty'},
#                                                                 {   'contentType': 'application/json',
#                                                                     'href': 'inproc://example-test',
#                                                                     'op': 'writeproperty'}],
#                                                    'type': 'number'},
#                       'db_init_int_prop': {   'default': 1,
#                                               'description': 'An integer '
#                                                              'property to '
#                                                              'check '
#                                                              'initialization '
#                                                              'from db',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'writeproperty'}],
#                                               'type': 'integer'},
#                       'db_persist_selector_prop': {   'default': 'a',
#                                                       'description': 'A '
#                                                                      'selector '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'persistence '
#                                                                      'to db on '
#                                                                      'write '
#                                                                      'operations',
#                                                       'enum': [   'a',
#                                                                   'b',
#                                                                   'c',
#                                                                   1],
#                                                       'forms': [   {   'contentType': 'application/json',
#                                                                        'href': 'inproc://example-test',
#                                                                        'op': 'readproperty'},
#                                                                    {   'contentType': 'application/json',
#                                                                        'href': 'inproc://example-test',
#                                                                        'op': 'writeproperty'}],
#                                                       'oneOf': [   {   'type': 'string'},
#                                                                    {   'type': 'integer'}]},
#                       'deletable_class_prop': {   'default': 100,
#                                                   'description': 'deletable '
#                                                                  'class '
#                                                                  'property '
#                                                                  'with custom '
#                                                                  'deleter',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'writeproperty'}],
#                                                   'type': 'number'},
#                       'int_prop': {   'default': 5,
#                                       'description': 'An integer property with '
#                                                      'step and bounds '
#                                                      'constraints to check RW',
#                                       'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'readproperty'},
#                                                    {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'writeproperty'}],
#                                       'maximum': 100,
#                                       'minimum': 0,
#                                       'multipleOf': 2,
#                                       'type': 'integer'},
#                       'json_schema_prop': {   'description': 'A property with '
#                                                              'a json schema to '
#                                                              'check RW',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'writeproperty'}],
#                                               'oneOf': [   {'type': 'null'},
#                                                            {   'maxLength': 10,
#                                                                'minLength': 1,
#                                                                'pattern': '^[a-z]+$',
#                                                                'type': 'string'}]},
#                       'managed_class_prop': {   'default': 0.0,
#                                                 'description': '(managed) '
#                                                                'class property '
#                                                                'with custom '
#                                                                'getter/setter',
#                                                 'forms': [   {   'contentType': 'application/json',
#                                                                  'href': 'inproc://example-test',
#                                                                  'op': 'readproperty'},
#                                                              {   'contentType': 'application/json',
#                                                                  'href': 'inproc://example-test',
#                                                                  'op': 'writeproperty'}],
#                                                 'type': 'number'},
#                       'not_a_class_prop': {   'default': 43,
#                                               'description': 'test property '
#                                                              'with '
#                                                              'class_member=False',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'writeproperty'}],
#                                               'type': 'number'},
#                       'number_prop': {   'default': 1,
#                                          'description': 'A fully editable '
#                                                         'number property',
#                                          'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'readproperty'},
#                                                       {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'writeproperty'}],
#                                          'type': 'number'},
#                       'observable_list_prop': {   'description': 'An '
#                                                                  'observable '
#                                                                  'list '
#                                                                  'property to '
#                                                                  'check '
#                                                                  'observable '
#                                                                  'events on '
#                                                                  'write '
#                                                                  'operations',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'writeproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test/event-publisher',
#                                                                    'op': 'observeproperty'}],
#                                                   'observable': True,
#                                                   'oneOf': [   {   'type': 'array'},
#                                                                {   'type': 'null'}]},
#                       'observable_readonly_prop': {   'default': 0,
#                                                       'description': 'An '
#                                                                      'observable '
#                                                                      'readonly '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'observable '
#                                                                      'events '
#                                                                      'on read '
#                                                                      'operations',
#                                                       'forms': [   {   'contentType': 'application/json',
#                                                                        'href': 'inproc://example-test',
#                                                                        'op': 'readproperty'},
#                                                                    {   'contentType': 'application/json',
#                                                                        'href': 'inproc://example-test/event-publisher',
#                                                                        'op': 'observeproperty'}],
#                                                       'observable': True,
#                                                       'readOnly': True,
#                                                       'type': 'number'},
#                       'pydantic_prop': {   'description': 'A property with a '
#                                                           'pydantic model to '
#                                                           'check RW',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'writeproperty'}],
#                                            'oneOf': [   {'type': 'null'},
#                                                         {   'properties': {   'bar': {   'type': 'integer'},
#                                                                               'foo': {   'type': 'string'},
#                                                                               'foo_bar': {   'type': 'number'}},
#                                                             'required': [   'foo',
#                                                                             'bar',
#                                                                             'foo_bar'],
#                                                             'type': 'object'}]},
#                       'pydantic_simple_prop': {   'description': 'A property '
#                                                                  'with a '
#                                                                  'simple '
#                                                                  'pydantic '
#                                                                  'model to '
#                                                                  'check RW',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'writeproperty'}],
#                                                   'oneOf': [   {'type': 'null'},
#                                                                {   'type': 'integer'}]},
#                       'readonly_class_prop': {   'default': '',
#                                                  'description': 'read-only '
#                                                                 'class '
#                                                                 'property',
#                                                  'forms': [   {   'contentType': 'application/json',
#                                                                   'href': 'inproc://example-test',
#                                                                   'op': 'readproperty'}],
#                                                  'readOnly': True,
#                                                  'type': 'string'},
#                       'selector_prop': {   'default': 'a',
#                                            'description': 'A selector property '
#                                                           'to check RW',
#                                            'enum': ['a', 'b', 'c', 1],
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'writeproperty'}],
#                                            'oneOf': [   {'type': 'string'},
#                                                         {'type': 'integer'}]},
#                       'simple_class_prop': {   'default': 42,
#                                                'description': 'simple class '
#                                                               'property with '
#                                                               'default value',
#                                                'forms': [   {   'contentType': 'application/json',
#                                                                 'href': 'inproc://example-test',
#                                                                 'op': 'readproperty'},
#                                                             {   'contentType': 'application/json',
#                                                                 'href': 'inproc://example-test',
#                                                                 'op': 'writeproperty'}],
#                                                'type': 'number'},
#                       'sleeping_prop': {   'default': 0,
#                                            'description': 'A property that '
#                                                           'sleeps for 10 '
#                                                           'seconds on read '
#                                                           'operations',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test/event-publisher',
#                                                             'op': 'observeproperty'}],
#                                            'observable': True,
#                                            'readOnly': True,
#                                            'type': 'number'},
#                       'string_prop': {   'default': 'hello',
#                                          'description': 'A string property '
#                                                         'with a regex '
#                                                         'constraint to check '
#                                                         'value errors',
#                                          'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'readproperty'},
#                                                       {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'writeproperty'}],
#                                          'pattern': '^[a-z]+',
#                                          'type': 'string'},
#                       'total_number_of_events': {   'default': 100,
#                                                     'description': 'Total '
#                                                                    'number of '
#                                                                    'events '
#                                                                    'pushed',
#                                                     'forms': [   {   'contentType': 'application/json',
#                                                                      'href': 'inproc://example-test',
#                                                                      'op': 'readproperty'},
#                                                                  {   'contentType': 'application/json',
#                                                                      'href': 'inproc://example-test',
#                                                                      'op': 'writeproperty'}],
#                                                     'minimum': 1,
#                                                     'type': 'number'}},
#     'title': 'TestThing'}

# %%
from hololinked.client.factory import ClientFactory

object_proxy = ClientFactory.zmq(server_id="example-test", thing_id="example-test", protocol="IPC", ignore_TD_errors=True)
pprint(object_proxy.td, indent=4)
# Out:
# INFO     - 2025-09-06T19:14:22:745 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: ROUTER with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test.ipc & identity: example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab|sync and connected
# INFO     - 2025-09-06T19:14:22:746 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - sent Handshake to server 'example-test'
# INFO     - 2025-09-06T19:14:22:749 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - client 'example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab|sync' handshook with server 'example-test'
# INFO     - 2025-09-06T19:14:22:754 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: ROUTER with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test.ipc & identity: example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab|async and connected
# INFO     - 2025-09-06T19:14:22:789 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|observable_list_prop|sync and connected
# INFO     - 2025-09-06T19:14:22:794 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|observable_list_prop|async and connected
# INFO     - 2025-09-06T19:14:22:800 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|observable_readonly_prop|sync and connected
# INFO     - 2025-09-06T19:14:22:806 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|observable_readonly_prop|async and connected
# INFO     - 2025-09-06T19:14:22:812 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|sleeping_prop|sync and connected
# INFO     - 2025-09-06T19:14:22:818 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|sleeping_prop|async and connected
# INFO     - 2025-09-06T19:14:22:824 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|data_point_event|sync and connected
# INFO     - 2025-09-06T19:14:22:829 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|data_point_event|async and connected
# INFO     - 2025-09-06T19:14:22:833 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_binary_payload_event|sync and connected
# INFO     - 2025-09-06T19:14:22:838 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_binary_payload_event|async and connected
# INFO     - 2025-09-06T19:14:22:842 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event|sync and connected
# INFO     - 2025-09-06T19:14:22:845 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event|async and connected
# INFO     - 2025-09-06T19:14:22:849 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event_with_json_schema|sync and connected
# INFO     - 2025-09-06T19:14:22:853 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event_with_json_schema|async and connected
# INFO     - 2025-09-06T19:14:22:858 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event_with_pydantic_schema|sync and connected
# INFO     - 2025-09-06T19:14:22:862 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event_with_pydantic_schema|async and connected
# INFO     - 2025-09-06T19:14:22:865 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_mixed_content_payload_event|sync and connected
# INFO     - 2025-09-06T19:14:22:869 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_mixed_content_payload_event|async and connected
# {   'actions': {   'action_echo': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'invokeaction'}],
#                                       'synchronous': True},
#                    'execute_instruction': {   'description': 'executes '
#                                                              'instruction '
#                                                              'given by the '
#                                                              'ASCII string '
#                                                              'parameter '
#                                                              "'command'. If "
#                                                              'return data size '
#                                                              'is greater than '
#                                                              '0, it reads the '
#                                                              'response and '
#                                                              'returns the '
#                                                              'response. Return '
#                                                              'Data Size - in '
#                                                              'bytes - 1 ASCII '
#                                                              'character = 1 '
#                                                              'Byte.',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'invokeaction'}],
#                                               'input': {   'properties': {   'command': {   'type': 'string'},
#                                                                              'return_data_size': {   'default': 0,
#                                                                                                      'minimum': 0,
#                                                                                                      'type': 'integer'}},
#                                                            'required': [   'command'],
#                                                            'type': 'object'},
#                                               'output': {'type': 'string'},
#                                               'synchronous': True},
#                    'exit': {   'description': 'Stop serving the object. This '
#                                               'method can only be called '
#                                               'remotely',
#                                'forms': [   {   'contentType': 'application/json',
#                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                 'op': 'invokeaction'}],
#                                'synchronous': True},
#                    'get_analogue_offset': {   'description': 'analogue offset '
#                                                              'for a voltage '
#                                                              'range and '
#                                                              'coupling',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'invokeaction'}],
#                                               'input': {   'properties': {   'coupling': {   'enum': [   'AC',
#                                                                                                          'DC'],
#                                                                                              'type': 'string'},
#                                                                              'voltage_range': {   'enum': [   '10mV',
#                                                                                                               '20mV',
#                                                                                                               '50mV',
#                                                                                                               '100mV',
#                                                                                                               '200mV',
#                                                                                                               '500mV',
#                                                                                                               '1V',
#                                                                                                               '2V',
#                                                                                                               '5V',
#                                                                                                               '10V',
#                                                                                                               '20V',
#                                                                                                               '50V',
#                                                                                                               'MAX_RANGES'],
#                                                                                                   'type': 'string'}},
#                                                            'type': 'object'},
#                                               'output': {   'items': {   'type': 'number'},
#                                                             'maxItems': 2,
#                                                             'minItems': 2,
#                                                             'type': 'array'},
#                                               'synchronous': True},
#                    'get_mixed_content_data': {   'forms': [   {   'contentType': 'application/json',
#                                                                   'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                   'op': 'invokeaction'}],
#                                                  'synchronous': True},
#                    'get_non_remote_number_prop': {   'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                       'op': 'invokeaction'}],
#                                                      'synchronous': True},
#                    'get_serialized_data': {   'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'invokeaction'}],
#                                               'synchronous': True},
#                    'get_thing_model': {   'description': 'generate the [Thing '
#                                                          'Model](https://www.w3.org/TR/wot-thing-description11/#introduction-tm) '
#                                                          'of the object. The '
#                                                          'model is a JSON that '
#                                                          'describes the '
#                                                          "object's properties, "
#                                                          'actions, events and '
#                                                          'their metadata, '
#                                                          'without the protocol '
#                                                          'information. The '
#                                                          'model can be used by '
#                                                          'a client to '
#                                                          'understand the '
#                                                          "object's "
#                                                          'capabilities.',
#                                           'forms': [   {   'contentType': 'application/json',
#                                                            'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                            'op': 'invokeaction'}],
#                                           'input': {   'properties': {   'ignore_errors': {   'default': False,
#                                                                                               'type': 'boolean'},
#                                                                          'skip_names': {   'default': [   ],
#                                                                                            'items': {   'type': 'string'},
#                                                                                            'type': 'array'}},
#                                                        'type': 'object'},
#                                           'synchronous': True},
#                    'get_transports': {   'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'invokeaction'}],
#                                          'synchronous': True},
#                    'ping': {   'description': 'ping the `Thing` to see if it '
#                                               'is alive. Ping successful when '
#                                               'action succeeds with no return '
#                                               'value and no timeout or '
#                                               'exception raised on the client '
#                                               'side.',
#                                'forms': [   {   'contentType': 'application/json',
#                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                 'op': 'invokeaction'}],
#                                'synchronous': True},
#                    'print_props': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'invokeaction'}],
#                                       'synchronous': True},
#                    'push_events': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'invokeaction'}],
#                                       'input': {   'properties': {   'event_name': {   'default': 'test_event',
#                                                                                        'type': 'string'},
#                                                                      'total_number_of_events': {   'default': 100,
#                                                                                                    'type': 'integer'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel': {   'description': 'Set the parameter for a '
#                                                      'channel. '
#                                                      'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                       'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'invokeaction'}],
#                                       'input': {   'properties': {   'bw_limiter': {   'enum': [   'full',
#                                                                                                    '20MHz'],
#                                                                                        'type': 'string'},
#                                                                      'channel': {   'enum': [   'A',
#                                                                                                 'B',
#                                                                                                 'C',
#                                                                                                 'D'],
#                                                                                     'type': 'string'},
#                                                                      'coupling': {   'enum': [   'AC',
#                                                                                                  'DC'],
#                                                                                      'type': 'string'},
#                                                                      'enabled': {   'type': 'boolean'},
#                                                                      'offset': {   'type': 'number'},
#                                                                      'voltage_range': {   'enum': [   '10mV',
#                                                                                                       '20mV',
#                                                                                                       '50mV',
#                                                                                                       '100mV',
#                                                                                                       '200mV',
#                                                                                                       '500mV',
#                                                                                                       '1V',
#                                                                                                       '2V',
#                                                                                                       '5V',
#                                                                                                       '10V',
#                                                                                                       '20V',
#                                                                                                       '50V',
#                                                                                                       'MAX_RANGES'],
#                                                                                           'type': 'string'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel_pydantic': {   'description': 'Set the '
#                                                               'parameter for a '
#                                                               'channel. '
#                                                               'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                                'forms': [   {   'contentType': 'application/json',
#                                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                 'op': 'invokeaction'}],
#                                                'input': {   'properties': {   'bw_limiter': {   'default': 'full',
#                                                                                                 'enum': [   'full',
#                                                                                                             '20MHz'],
#                                                                                                 'type': 'string'},
#                                                                               'channel': {   'enum': [   'A',
#                                                                                                          'B',
#                                                                                                          'C',
#                                                                                                          'D'],
#                                                                                              'type': 'string'},
#                                                                               'coupling': {   'default': 'DC_1M',
#                                                                                               'enum': [   'AC',
#                                                                                                           'DC'],
#                                                                                               'type': 'string'},
#                                                                               'enabled': {   'default': True,
#                                                                                              'type': 'boolean'},
#                                                                               'offset': {   'default': 0,
#                                                                                             'type': 'number'},
#                                                                               'v_range': {   'default': '2V',
#                                                                                              'enum': [   '10mV',
#                                                                                                          '20mV',
#                                                                                                          '50mV',
#                                                                                                          '100mV',
#                                                                                                          '200mV',
#                                                                                                          '500mV',
#                                                                                                          '1V',
#                                                                                                          '2V',
#                                                                                                          '5V',
#                                                                                                          '10V',
#                                                                                                          '20V',
#                                                                                                          '50V',
#                                                                                                          'MAX_RANGES'],
#                                                                                              'type': 'string'}},
#                                                             'required': [   'channel'],
#                                                             'type': 'object'},
#                                                'synchronous': True},
#                    'set_non_remote_number_prop': {   'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                       'op': 'invokeaction'}],
#                                                      'synchronous': True},
#                    'set_sensor_model': {   'description': 'Set the attached '
#                                                           'sensor to the meter '
#                                                           'under control. '
#                                                           'Sensor should be '
#                                                           'defined as a class '
#                                                           'and added to the '
#                                                           'AllowedSensors '
#                                                           'dict.',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'invokeaction'}],
#                                            'input': {   'enum': [   'QE25LP-S-MB',
#                                                                     'QE12LP-S-MB-QED-D0'],
#                                                         'type': 'string'},
#                                            'synchronous': True},
#                    'set_sensor_model_pydantic': {   'description': 'Set the '
#                                                                    'attached '
#                                                                    'sensor to '
#                                                                    'the meter '
#                                                                    'under '
#                                                                    'control. '
#                                                                    'Sensor '
#                                                                    'should be '
#                                                                    'defined as '
#                                                                    'a class '
#                                                                    'and added '
#                                                                    'to the '
#                                                                    'AllowedSensors '
#                                                                    'dict.',
#                                                     'forms': [   {   'contentType': 'application/json',
#                                                                      'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                      'op': 'invokeaction'}],
#                                                     'input': {   'properties': {   'value': {   'enum': [   'QE25LP-S-MB',
#                                                                                                             'QE12LP-S-MB-QED-D0'],
#                                                                                                 'type': 'string'}},
#                                                                  'required': [   'value'],
#                                                                  'type': 'object'},
#                                                     'synchronous': True},
#                    'sleep': {   'forms': [   {   'contentType': 'application/json',
#                                                  'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                  'op': 'invokeaction'}],
#                                 'synchronous': True},
#                    'start_acquisition': {   'description': 'Start acquisition '
#                                                            'of energy '
#                                                            'measurements.',
#                                             'forms': [   {   'contentType': 'application/json',
#                                                              'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                              'op': 'invokeaction'}],
#                                             'input': {   'properties': {   'max_count': {   'exclusiveMinimum': 0,
#                                                                                             'type': 'integer'}},
#                                                          'required': [   'max_count'],
#                                                          'type': 'object'},
#                                             'synchronous': True}},
#     'context': ['https://www.w3.org/2022/wot/td/v1.1'],
#     'events': {   'data_point_event': {   'data': {   'properties': {   'energy': {   'type': 'number'},
#                                                                         'timestamp': {   'type': 'string'}},
#                                                       'required': [   'timestamp',
#                                                                       'energy'],
#                                                       'type': 'object'},
#                                           'description': 'Event raised when a '
#                                                          'new data point is '
#                                                          'available',
#                                           'forms': [   {   'contentType': 'application/json',
#                                                            'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                            'op': 'subscribeevent'}]},
#                   'test_binary_payload_event': {   'description': 'test event '
#                                                                   'with binary '
#                                                                   'payload',
#                                                    'forms': [   {   'contentType': 'application/json',
#                                                                     'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                     'op': 'subscribeevent'}]},
#                   'test_event': {   'description': 'test event with arbitrary '
#                                                    'payload',
#                                     'forms': [   {   'contentType': 'application/json',
#                                                      'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                      'op': 'subscribeevent'}]},
#                   'test_event_with_json_schema': {   'description': 'test '
#                                                                     'event '
#                                                                     'with '
#                                                                     'schema '
#                                                                     'validation',
#                                                      'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                       'op': 'subscribeevent'}]},
#                   'test_event_with_pydantic_schema': {   'description': 'test '
#                                                                         'event '
#                                                                         'with '
#                                                                         'pydantic '
#                                                                         'schema '
#                                                                         'validation',
#                                                          'forms': [   {   'contentType': 'application/json',
#                                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                           'op': 'subscribeevent'}]},
#                   'test_mixed_content_payload_event': {   'description': 'test '
#                                                                          'event '
#                                                                          'with '
#                                                                          'mixed '
#                                                                          'content '
#                                                                          'payload',
#                                                           'forms': [   {   'contentType': 'application/json',
#                                                                            'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                            'op': 'subscribeevent'}]}},
#     'id': 'example-test',
#     'properties': {   'db_commit_number_prop': {   'default': 0,
#                                                    'description': 'A fully '
#                                                                   'editable '
#                                                                   'number '
#                                                                   'property to '
#                                                                   'check '
#                                                                   'commits to '
#                                                                   'db on write '
#                                                                   'operations',
#                                                    'forms': [   {   'contentType': 'application/json',
#                                                                     'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                     'op': 'readproperty'},
#                                                                 {   'contentType': 'application/json',
#                                                                     'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                     'op': 'writeproperty'}],
#                                                    'type': 'number'},
#                       'db_init_int_prop': {   'default': 1,
#                                               'description': 'An integer '
#                                                              'property to '
#                                                              'check '
#                                                              'initialization '
#                                                              'from db',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'writeproperty'}],
#                                               'type': 'integer'},
#                       'db_persist_selector_prop': {   'default': 'a',
#                                                       'description': 'A '
#                                                                      'selector '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'persistence '
#                                                                      'to db on '
#                                                                      'write '
#                                                                      'operations',
#                                                       'enum': [   'a',
#                                                                   'b',
#                                                                   'c',
#                                                                   1],
#                                                       'forms': [   {   'contentType': 'application/json',
#                                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                        'op': 'readproperty'},
#                                                                    {   'contentType': 'application/json',
#                                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                        'op': 'writeproperty'}],
#                                                       'oneOf': [   {   'type': 'string'},
#                                                                    {   'type': 'integer'}]},
#                       'deletable_class_prop': {   'default': 100,
#                                                   'description': 'deletable '
#                                                                  'class '
#                                                                  'property '
#                                                                  'with custom '
#                                                                  'deleter',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'writeproperty'}],
#                                                   'type': 'number'},
#                       'int_prop': {   'default': 5,
#                                       'description': 'An integer property with '
#                                                      'step and bounds '
#                                                      'constraints to check RW',
#                                       'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'readproperty'},
#                                                    {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'writeproperty'}],
#                                       'maximum': 100,
#                                       'minimum': 0,
#                                       'multipleOf': 2,
#                                       'type': 'integer'},
#                       'json_schema_prop': {   'description': 'A property with '
#                                                              'a json schema to '
#                                                              'check RW',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'writeproperty'}],
#                                               'oneOf': [   {'type': 'null'},
#                                                            {   'maxLength': 10,
#                                                                'minLength': 1,
#                                                                'pattern': '^[a-z]+$',
#                                                                'type': 'string'}]},
#                       'managed_class_prop': {   'default': 0.0,
#                                                 'description': '(managed) '
#                                                                'class property '
#                                                                'with custom '
#                                                                'getter/setter',
#                                                 'forms': [   {   'contentType': 'application/json',
#                                                                  'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                  'op': 'readproperty'},
#                                                              {   'contentType': 'application/json',
#                                                                  'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                  'op': 'writeproperty'}],
#                                                 'type': 'number'},
#                       'not_a_class_prop': {   'default': 43,
#                                               'description': 'test property '
#                                                              'with '
#                                                              'class_member=False',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'writeproperty'}],
#                                               'type': 'number'},
#                       'number_prop': {   'default': 1,
#                                          'description': 'A fully editable '
#                                                         'number property',
#                                          'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'readproperty'},
#                                                       {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'writeproperty'}],
#                                          'type': 'number'},
#                       'observable_list_prop': {   'description': 'An '
#                                                                  'observable '
#                                                                  'list '
#                                                                  'property to '
#                                                                  'check '
#                                                                  'observable '
#                                                                  'events on '
#                                                                  'write '
#                                                                  'operations',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'writeproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                    'op': 'observeproperty'}],
#                                                   'observable': True,
#                                                   'oneOf': [   {   'type': 'array'},
#                                                                {   'type': 'null'}]},
#                       'observable_readonly_prop': {   'default': 0,
#                                                       'description': 'An '
#                                                                      'observable '
#                                                                      'readonly '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'observable '
#                                                                      'events '
#                                                                      'on read '
#                                                                      'operations',
#                                                       'forms': [   {   'contentType': 'application/json',
#                                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                        'op': 'readproperty'},
#                                                                    {   'contentType': 'application/json',
#                                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                        'op': 'observeproperty'}],
#                                                       'observable': True,
#                                                       'readOnly': True,
#                                                       'type': 'number'},
#                       'pydantic_prop': {   'description': 'A property with a '
#                                                           'pydantic model to '
#                                                           'check RW',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'writeproperty'}],
#                                            'oneOf': [   {'type': 'null'},
#                                                         {   'properties': {   'bar': {   'type': 'integer'},
#                                                                               'foo': {   'type': 'string'},
#                                                                               'foo_bar': {   'type': 'number'}},
#                                                             'required': [   'foo',
#                                                                             'bar',
#                                                                             'foo_bar'],
#                                                             'type': 'object'}]},
#                       'pydantic_simple_prop': {   'description': 'A property '
#                                                                  'with a '
#                                                                  'simple '
#                                                                  'pydantic '
#                                                                  'model to '
#                                                                  'check RW',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'writeproperty'}],
#                                                   'oneOf': [   {'type': 'null'},
#                                                                {   'type': 'integer'}]},
#                       'readonly_class_prop': {   'default': '',
#                                                  'description': 'read-only '
#                                                                 'class '
#                                                                 'property',
#                                                  'forms': [   {   'contentType': 'application/json',
#                                                                   'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                   'op': 'readproperty'}],
#                                                  'readOnly': True,
#                                                  'type': 'string'},
#                       'selector_prop': {   'default': 'a',
#                                            'description': 'A selector property '
#                                                           'to check RW',
#                                            'enum': ['a', 'b', 'c', 1],
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'writeproperty'}],
#                                            'oneOf': [   {'type': 'string'},
#                                                         {'type': 'integer'}]},
#                       'simple_class_prop': {   'default': 42,
#                                                'description': 'simple class '
#                                                               'property with '
#                                                               'default value',
#                                                'forms': [   {   'contentType': 'application/json',
#                                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                 'op': 'readproperty'},
#                                                             {   'contentType': 'application/json',
#                                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                 'op': 'writeproperty'}],
#                                                'type': 'number'},
#                       'sleeping_prop': {   'default': 0,
#                                            'description': 'A property that '
#                                                           'sleeps for 10 '
#                                                           'seconds on read '
#                                                           'operations',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                             'op': 'observeproperty'}],
#                                            'observable': True,
#                                            'readOnly': True,
#                                            'type': 'number'},
#                       'string_prop': {   'default': 'hello',
#                                          'description': 'A string property '
#                                                         'with a regex '
#                                                         'constraint to check '
#                                                         'value errors',
#                                          'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'readproperty'},
#                                                       {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'writeproperty'}],
#                                          'pattern': '^[a-z]+',
#                                          'type': 'string'},
#                       'total_number_of_events': {   'default': 100,
#                                                     'description': 'Total '
#                                                                    'number of '
#                                                                    'events '
#                                                                    'pushed',
#                                                     'forms': [   {   'contentType': 'application/json',
#                                                                      'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                      'op': 'readproperty'},
#                                                                  {   'contentType': 'application/json',
#                                                                      'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                      'op': 'writeproperty'}],
#                                                     'minimum': 1,
#                                                     'type': 'number'}},
#     'title': 'TestThing'}
# INFO     - 2025-09-06T19:14:22:894 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - sent Handshake to server 'example-test'
# INFO     - 2025-09-06T19:14:22:896 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - client 'example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab|async' handshook with server 'example-test'

# %%
TestThing.get_analogue_offset.to_affordance().json()
# Out:
# {'description': 'analogue offset for a voltage range and coupling',
#  'input': {'type': 'object',
#   'properties': {'voltage_range': {'type': 'string',
#     'enum': ['10mV',
#      '20mV',
#      '50mV',
#      '100mV',
#      '200mV',
#      '500mV',
#      '1V',
#      '2V',
#      '5V',
#      '10V',
#      '20V',
#      '50V',
#      'MAX_RANGES']},
#    'coupling': {'type': 'string', 'enum': ['AC', 'DC']}}},
#  'output': {'type': 'array',
#   'minItems': 2,
#   'maxItems': 2,
#   'items': {'type': 'number'}},
#  'synchronous': True}

# %%
TestThing.set_channel.to_affordance().json()
# Out:
# {'description': 'Set the parameter for a channel. https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#  'input': {'type': 'object',
#   'properties': {'channel': {'type': 'string', 'enum': ['A', 'B', 'C', 'D']},
#    'enabled': {'type': 'boolean'},
#    'voltage_range': {'type': 'string',
#     'enum': ['10mV',
#      '20mV',
#      '50mV',
#      '100mV',
#      '200mV',
#      '500mV',
#      '1V',
#      '2V',
#      '5V',
#      '10V',
#      '20V',
#      '50V',
#      'MAX_RANGES']},
#    'offset': {'type': 'number'},
#    'coupling': {'type': 'string', 'enum': ['AC', 'DC']},
#    'bw_limiter': {'type': 'string', 'enum': ['full', '20MHz']}}},
#  'synchronous': True}

# %%
TestThing.set_sensor_model.to_affordance().json()
# Out:
# {'description': 'Set the attached sensor to the meter under control. Sensor should be defined as a class and added to the AllowedSensors dict.',
#  'input': {'type': 'string', 'enum': ['QE25LP-S-MB', 'QE12LP-S-MB-QED-D0']},
#  'synchronous': True}

# %%
TestThing.set_channel_pydantic.to_affordance().json()
# Out:
# {'description': 'Set the parameter for a channel. https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#  'input': {'properties': {'channel': {'enum': ['A', 'B', 'C', 'D'],
#     'type': 'string'},
#    'enabled': {'default': True, 'type': 'boolean'},
#    'v_range': {'default': '2V',
#     'enum': ['10mV',
#      '20mV',
#      '50mV',
#      '100mV',
#      '200mV',
#      '500mV',
#      '1V',
#      '2V',
#      '5V',
#      '10V',
#      '20V',
#      '50V',
#      'MAX_RANGES'],
#     'type': 'string'},
#    'offset': {'default': 0, 'type': 'number'},
#    'coupling': {'default': 'DC_1M', 'enum': ['AC', 'DC'], 'type': 'string'},
#    'bw_limiter': {'default': 'full',
#     'enum': ['full', '20MHz'],
#     'type': 'string'}},
#   'required': ['channel'],
#   'type': 'object'},
#  'synchronous': True}

# %%
from hololinked.utils import get_input_model_from_signature

get_input_model_from_signature(TestThing.set_channel_pydantic.obj)
# Out:
# hololinked.utils.set_channel_pydantic_input

# %%
TestThing.start_acquisition.to_affordance().json()
# Out:
# {'description': 'Start acquisition of energy measurements.',
#  'input': {'properties': {'max_count': {'exclusiveMinimum': 0,
#     'type': 'integer'}},
#   'required': ['max_count'],
#   'type': 'object'},
#  'synchronous': True}

# %%
TestThing.execute_instruction.to_affordance().json()
# Out:
# {'description': "executes instruction given by the ASCII string parameter 'command'. If return data size is greater than 0, it reads the response and returns the response. Return Data Size - in bytes - 1 ASCII character = 1 Byte.",
#  'input': {'properties': {'command': {'type': 'string'},
#    'return_data_size': {'default': 0, 'minimum': 0, 'type': 'integer'}},
#   'required': ['command'],
#   'type': 'object'},
#  'output': {'format': 'binary', 'type': 'string'},
#  'synchronous': True}

# %%
TestThing.data_point_event.to_affordance().json()
# Out:
# {'description': 'Event raised when a new data point is available',
#  'data': {'type': 'object',
#   'properties': {'timestamp': {'type': 'string'},
#    'energy': {'type': 'number'}},
#   'required': ['timestamp', 'energy']}}

# %%
TestThing.numpy_action.to_affordance().json()
# Out:
# {'input': {'properties': {'array': {'items': {'type': 'number'},
#     'type': 'array'}},
#   'required': ['array'],
#   'type': 'object'},
#  'output': {'items': {'type': 'number'}, 'type': 'array'},
#  'synchronous': True}

# %%
from hololinked.client import ClientFactory

mqtt_ssl = ssl.create_default_context(ssl.Purpose.SERVER_AUTH)
if not os.path.exists("ca.crt"):
    raise FileNotFoundError("CA certificate 'ca.crt' not found in current directory for MQTT TLS connection")
mqtt_ssl.load_verify_locations(cafile="ca.crt")
mqtt_ssl.check_hostname = True
mqtt_ssl.verify_mode = ssl.CERT_REQUIRED
mqtt_ssl.minimum_version = ssl.TLSVersion.TLSv1_2

object_proxy_http = ClientFactory.http("http://localhost:9000/example-test/resources/wot-td", ignore_TD_errors=True)
object_proxy_mqtt = ClientFactory.mqtt(hostname="localhost", port=8883, thing_id="example-test", ssl_context=mqtt_ssl, username="sampleuser", password="samplepass")
# object_proxy_zmq = ClientFactory.zmq(server_id="example-test-server", thing_id="example-test", access_point="IPC", ignore_TD_errors=True)
object_proxy_mqtt.td
# Out:
# {'context': ['https://www.w3.org/2022/wot/td/v1.1'],
#  'id': 'example-test',
#  'title': 'TestThing',
#  'description': 'A test thing with various API options for properties, actions and events that were collected from examples from real world implementations, testing, features offered etc.  Add your own use case/snippets used in tests here as needed.',
#  'properties': {'observable_list_prop': {'description': 'An observable list property to check observable events on write operations',
#    'oneOf': [{'type': 'array'}, {'type': 'null'}],
#    'observable': True,
#    'forms': [{'href': 'mqtt://localhost:8883',
#      'op': 'observeproperty',
#      'contentType': 'application/json'}]},
#   'observable_readonly_prop': {'description': 'An observable readonly property to check observable events on read operations',
#    'default': 0,
#    'readOnly': True,
#    'type': 'number',
#    'observable': True,
#    'forms': [{'href': 'mqtt://localhost:8883',
#      'op': 'observeproperty',
#      'contentType': 'application/json'}]},
#   'sleeping_prop': {'description': 'A property that sleeps for 10 seconds on read operations',
#    'default': 0,
#    'readOnly': True,
#    'type': 'number',
#    'observable': True,
#    'forms': [{'href': 'mqtt://localhost:8883',
#      'op': 'observeproperty',
#      'contentType': 'application/json'}]}},
#  'events': {'data_point_event': {'description': 'Event raised when a new data point is available',
#    'data': {'type': 'object',
#     'properties': {'timestamp': {'type': 'string'},
#      'energy': {'type': 'number'}},
#     'required': ['timestamp', 'energy']},
#    'forms': [{'href': 'mqtt://localhost:8883',
#      'op': 'subscribeevent',
#      'contentType': 'application/json'}]},
#   'test_binary_payload_event': {'description': 'test event with binary payload',
#    'forms': [{'href': 'mqtt://localhost:8883',
#      'op': 'subscribeevent',
#      'contentType': 'application/json'}]},
#   'test_event': {'description': 'test event with arbitrary payload',
#    'forms': [{'href': 'mqtt://localhost:8883',
#      'op': 'subscribeevent',
#      'contentType': 'application/json'}]},
#   'test_event_with_json_schema': {'description': 'test event with schema validation',
#    'forms': [{'href': 'mqtt://localhost:8883',
#      'op': 'subscribeevent',
#      'contentType': 'application/json'}]},
#   'test_event_with_pydantic_schema': {'description': 'test event with pydantic schema validation',
#    'forms': [{'href': 'mqtt://localhost:8883',
#      'op': 'subscribeevent',
#      'contentType': 'application/json'}]},
#   'test_mixed_content_payload_event': {'description': 'test event with mixed content payload',
#    'forms': [{'href': 'mqtt://localhost:8883',
#      'op': 'subscribeevent',
#      'contentType': 'application/json'}]}}}

# %%
def cb(value):
    print("event0", threading.get_ident(), value.data)

def cb1(value):
    print("event1 ", threading.get_ident(), value.data)

def cb2(value):
    print("event2 ", threading.get_ident(), value.data)

async def async_cb1(value):
    print("event1 ", asyncio.current_task().get_name(), value.data)

async def async_cb2(value):
    print("event2 ", asyncio.current_task().get_name(), value.data)

# object_proxy.subscribe_event("test_event", cb)
# object_proxy.subscribe_event("test_event", [cb1, cb2], concurrent=True)
# object_proxy.subscribe_event("test_event", [async_cb1, async_cb2], asynch=True)
# object_proxy.subscribe_event("test_event", [async_cb1, async_cb2], asynch=True, concurrent=True)

# %%
object_proxy_mqtt.subscribe_event("test_event", cb)

# %%
object_proxy_mqtt.subscribe_event("test_event", [async_cb1, async_cb2], asynch=True, concurrent=True)
# Out:
# event1  Task-8 test data
# event2  Task-9 test data
# event1  Task-11 test data
# event2  Task-12 test data
# event1  Task-14 test data
# event2  Task-15 test data
# event1  Task-17 test data
# event2  Task-18 test data
# event1  Task-20 test data
# event2  Task-21 test data
# event1  Task-23 test data
# event2  Task-24 test data
# event1  Task-26 test data
# event2  Task-27 test data
# event1  Task-29 test data
# event2  Task-30 test data
# event1  Task-32 test data
# event2  Task-33 test data
# event1  Task-35 test data
# event2  Task-36 test data
# event1  Task-38 test data
# event2  Task-39 test data
# event1  Task-41 test data
# event2  Task-42 test data
# event1  Task-44 test data
# event2  Task-45 test data
# event1  Task-47 test data
# event2  Task-48 test data
# event1  Task-50 test data
# event2  Task-51 test data
# event1  Task-53 test data
# event2  Task-54 test data
# event1  Task-56 test data
# event2  Task-57 test data
# event1  Task-59 test data
# event2  Task-60 test data
# event1  Task-62 test data
# event2  Task-63 test data
# event1  Task-65 test data
# event2  Task-66 test data
# event1  Task-68 test data
# event2  Task-69 test data
# event1  Task-71 test data
# event2  Task-72 test data
# event1  Task-74 test data
# event2  Task-75 test data
# event1  Task-77 test data
# event2  Task-78 test data
# event1  Task-80 test data
# event2  Task-81 test data
# event1  Task-83 test data
# event2  Task-84 test data
# event1  Task-86 test data
# event2  Task-87 test data
# event1  Task-89 test data
# event2  Task-90 test data
# event1  Task-92 test data
# event2  Task-93 test data
# event1  Task-95 test data
# event2  Task-96 test data
# event1  Task-98 test data
# event2  Task-99 test data
# event1  Task-101 test data
# event2  Task-102 test data
# event1  Task-104 test data
# event2  Task-105 test data
# event1  Task-107 test data
# event2  Task-108 test data
# event1  Task-110 test data
# event2  Task-111 test data
# event1  Task-113 test data
# event2  Task-114 test data
# event1  Task-116 test data
# event2  Task-117 test data
# event1  Task-119 test data
# event2  Task-120 test data
# event1  Task-122 test data
# event2  Task-123 test data
# event1  Task-125 test data
# event2  Task-126 test data
# event1  Task-128 test data
# event2  Task-129 test data
# event1  Task-131 test data
# event2  Task-132 test data
# event1  Task-134 test data
# event2  Task-135 test data
# event1  Task-137 test data
# event2  Task-138 test data
# event1  Task-140 test data
# event2  Task-141 test data
# event1  Task-143 test data
# event2  Task-144 test data
# event1  Task-146 test data
# event2  Task-147 test data
# event1  Task-149 test data
# event2  Task-150 test data
# event1  Task-152 test data
# event2  Task-153 test data
# event1  Task-155 test data
# event2  Task-156 test data
# event1  Task-158 test data
# event2  Task-159 test data
# event1  Task-161 test data
# event2  Task-162 test data
# event1  Task-164 test data
# event2  Task-165 test data
# event1  Task-167 test data
# event2  Task-168 test data
# event1  Task-170 test data
# event2  Task-171 test data
# event1  Task-173 test data
# event2  Task-174 test data
# event1  Task-176 test data
# event2  Task-177 test data
# event1  Task-179 test data
# event2  Task-180 test data
# event1  Task-182 test data
# event2  Task-183 test data
# event1  Task-185 test data
# event2  Task-186 test data
# event1  Task-188 test data
# event2  Task-189 test data
# event1  Task-191 test data
# event2  Task-192 test data
# event1  Task-194 test data
# event2  Task-195 test data
# event1  Task-197 test data
# event2  Task-198 test data
# event1  Task-200 test data
# event2  Task-201 test data
# event1  Task-203 test data
# event2  Task-204 test data
# event1  Task-206 test data
# event2  Task-207 test data
# event1  Task-209 test data
# event2  Task-210 test data
# event1  Task-212 test data
# event2  Task-213 test data
# event1  Task-215 test data
# event2  Task-216 test data
# event1  Task-218 test data
# event2  Task-219 test data
# event1  Task-221 test data
# event2  Task-222 test data
# event1  Task-224 test data
# event2  Task-225 test data
# event1  Task-227 test data
# event2  Task-228 test data
# event1  Task-230 test data
# event2  Task-231 test data
# event1  Task-233 test data
# event2  Task-234 test data
# event1  Task-236 test data
# event2  Task-237 test data
# event1  Task-239 test data
# event2  Task-240 test data
# event1  Task-242 test data
# event2  Task-243 test data
# event1  Task-245 test data
# event2  Task-246 test data
# event1  Task-248 test data
# event2  Task-249 test data
# event1  Task-251 test data
# event2  Task-252 test data
# event1  Task-254 test data
# event2  Task-255 test data
# event1  Task-257 test data
# event2  Task-258 test data
# event1  Task-260 test data
# event2  Task-261 test data
# event1  Task-263 test data
# event2  Task-264 test data
# event1  Task-266 test data
# event2  Task-267 test data
# event1  Task-269 test data
# event2  Task-270 test data
# event1  Task-272 test data
# event2  Task-273 test data
# event1  Task-275 test data
# event2  Task-276 test data
# event1  Task-278 test data
# event2  Task-279 test data
# event1  Task-281 test data
# event2  Task-282 test data
# event1  Task-284 test data
# event2  Task-285 test data
# event1  Task-287 test data
# event2  Task-288 test data
# event1  Task-290 test data
# event2  Task-291 test data
# event1  Task-293 test data
# event2  Task-294 test data
# event1  Task-296 test data
# event2  Task-297 test data
# event1  Task-299 test data
# event2  Task-300 test data
# event1  Task-302 test data
# event2  Task-303 test data
# event1  Task-305 test data
# event2  Task-306 test data

# %%
object_proxy_mqtt.subscribe_event("test_binary_payload_event", callbacks=[cb1, cb2], concurrent=True)

# %%
object_proxy_http.push_events()

# %%
object_proxy_http.push_events(event_name="test_binary_payload_event")

# %%
object_proxy.unsubscribe_event("test_event")

# %%
for i in range(5):
    print(object_proxy.read_property("db_init_int_prop"), i)
# Out:
# 1 0
# 1 1
# 1 2
# 1 3
# 1 4

# %%
object_proxy_mqtt.read_property("db_init_int_prop")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 object_proxy_mqtt.read_property("db_init_int_prop")
#
# File D:\current projects\hololinked\hololinked\client\proxy.py:215, in ObjectProxy.read_property(self, name, noblock)
#     213 prop = self.__dict__.get(name, None)  # type: ConsumedThingProperty
#     214 if not isinstance(prop, ConsumedThingProperty):
# --> 215     raise AttributeError(f"No property named {name}")
#     216 if noblock:
#     217     return prop.noblock_get()
#
# AttributeError: No property named db_init_int_prop

# %%
object_proxy_zmq.set_non_remote_number_prop(20)
object_proxy_zmq.get_non_remote_number_prop()
# Out:
# 20

# %%
object_proxy_http.get_transports()
# Out:
# ['INPROC', 'IPC']

# %%
# object_proxy.get_serialized_data()
object_proxy_zmq.get_serialized_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # object_proxy.get_serialized_data()
# ----> 2 object_proxy_zmq.get_serialized_data()
#
# NameError: name 'object_proxy_zmq' is not defined

# %%
val, binary_val = object_proxy_zmq.get_mixed_content_data()
print(val)
print(binary_val)
# Out:
# foobar
# b'foobar'

# %%
# print(object_proxy.numpy_array_prop)
# print(type(object_proxy.numpy_array_prop))
print(object_proxy.numpy_action(object_proxy.numpy_array_prop))
# Out:
# [2 4 6]
