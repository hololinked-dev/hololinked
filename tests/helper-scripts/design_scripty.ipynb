# %%
import importlib
import os
import sys

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../")))

import hololinked
import things 

importlib.reload(hololinked)
importlib.reload(things)

from hololinked.core import Thing
from hololinked.constants import Operations


from things import OceanOpticsSpectrometer, TestThing

# %%
thing = TestThing(id='example-test')
thing.run(
    access_points=[
        ("ZMQ", ["tcp://*:5558", "IPC"]),
        ("HTTP", 8080),
    ],
    forked=True
)
# thing.run_with_zmq_server(['IPC', 'TCP'], forked=True)
# thing.run_with_http_server(forked=True)
# Out:
# INFO     - 2025-09-21T09:28:11:539 - example-test - initialialised Thing class TestThing with id example-test
# INFO     - 2025-09-21T09:28:11:543 - example-test - created socket type: ROUTER with address: inproc://example-test & identity: example-test and bound
# INFO     - 2025-09-21T09:28:11:547 - example-test - created socket type: PUB with address: inproc://example-test/event-publisher & identity: example-test/event-publisher and bound
# <Thread(Thread-7 (run), started daemon 6804)>
# INFO     - 2025-09-21T09:28:11:550 - example-test - created socket type: ROUTER with address: tcp://*:5558 & identity: example-test and bound
# INFO     - 2025-09-21T09:28:11:562 - example-test - created socket type: PUB with address: tcp://0.0.0.0:60000 & identity: example-test/event-publisher and bound
# INFO     - 2025-09-21T09:28:11:565 - example-test - created socket type: ROUTER with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test.ipc & identity: example-test and bound
# INFO     - 2025-09-21T09:28:11:568 - example-test - created socket type: PUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test/event-publisher and bound
# INFO     - 2025-09-21T09:28:11:570 - example-test - created socket type: SUB with address: inproc://example-test/event-publisher & identity: example-test/event-proxy and connected
# INFO     - 2025-09-21T09:28:11:627 - HTTPServer|0.0.0.0:8080 - created socket type: ROUTER with address: inproc://example-test & identity: 0.0.0.0:8080 and connected
# INFO     - 2025-09-21T09:28:11:630 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:12:131 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:12:132 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:12:646 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:12:647 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:13:161 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:13:162 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:13:664 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:13:664 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:14:176 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:14:177 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:14:681 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:14:682 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:15:193 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:15:194 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:15:697 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:15:698 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:16:211 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:16:212 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:16:717 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:16:717 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:17:227 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:17:228 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:17:734 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:17:734 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:18:245 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:18:246 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:18:751 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:18:752 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:19:260 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:19:261 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:19:767 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:19:768 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:20:269 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:20:270 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:20:779 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:20:780 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:21:285 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:21:285 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:21:798 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:21:799 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:22:304 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:22:304 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:22:817 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:22:818 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:23:322 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:23:322 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:23:835 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:23:836 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:24:339 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:24:340 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:24:851 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:24:852 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:25:356 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:25:357 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:25:867 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:25:867 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:26:373 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:26:374 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:26:885 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:26:886 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:27:391 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:27:392 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:27:905 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:27:906 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:28:409 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:28:410 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:28:920 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:28:920 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:29:427 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:29:428 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:29:940 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:29:940 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:30:444 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:30:445 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:30:956 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:30:956 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:31:461 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:31:462 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:31:974 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:31:975 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:32:478 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:32:479 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:32:991 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:32:992 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:33:495 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:33:496 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:34:009 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:34:010 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:34:514 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:34:515 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:35:025 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:35:025 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:35:531 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:35:532 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:36:048 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:36:049 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:36:564 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:36:565 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:37:066 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:37:067 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:37:580 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:37:581 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:38:083 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:38:084 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:38:596 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:38:598 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:39:101 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:39:102 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:39:612 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:39:614 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:40:119 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:40:120 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:40:631 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:40:632 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# INFO     - 2025-09-21T09:28:41:135 - HTTPServer|0.0.0.0:8080 - got no response for handshake
# INFO     - 2025-09-21T09:28:41:136 - HTTPServer|0.0.0.0:8080 - sent Handshake to server 'example-test'
# ERROR    - 2025-09-21T09:28:41:635 - HTTPServer|0.0.0.0:8080 - could not connect to example-test using on server example-test with access_point INPROC. error:
# INFO     - 2025-09-21T09:28:41:636 - example-test - starting RPC server example-test
# INFO     - 2025-09-21T09:28:41:638 - example-test - starting thing executor loop in thread 21816 for ['example-test']
# INFO     - 2025-09-21T09:28:41:642 - example-test - starting to run operations on thing example-test of class TestThing
# INFO     - 2025-09-21T09:28:41:642 - example-test - starting external message listener thread
# INFO     - 2025-09-21T09:28:41:647 - HTTPServer|0.0.0.0:8080 - started webserver at 0.0.0.0:8080, ready to receive requests.
# INFO     - 2025-09-21T09:28:41:650 - HTTPServer|0.0.0.0:8080 - client polling started for sockets for []
# INFO     - 2025-09-21T09:28:41:654 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:656 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:657 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:658 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:659 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:661 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:662 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:663 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:664 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:665 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:666 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:667 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:668 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:670 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:671 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:672 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:674 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:675 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:676 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:677 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:678 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:680 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:680 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:681 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:682 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:683 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:684 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:685 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:686 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:686 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:687 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:688 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:690 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:690 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:691 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:692 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:692 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:693 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:693 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:694 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:695 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:695 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:696 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:696 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:697 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:697 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:698 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:698 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:700 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:701 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:702 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:703 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:704 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:704 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:705 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:706 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:707 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:708 - example-test - sent handshake to client '0.0.0.0:8080'
# INFO     - 2025-09-21T09:28:41:709 - example-test - sent handshake to client '0.0.0.0:8080'

# %%
from pprint import pprint
pprint(thing.get_thing_model(ignore_errors=True).json(), indent=4)
# Out:
# ERROR    - 2025-09-06T19:14:17:728 - example-test - Error while generating schema for base_property - WoT schema generator for this descriptor/property is not implemented. name base_property & type <class 'hololinked.core.property.Property'>
# {   'actions': {   'action_echo': {'synchronous': True},
#                    'execute_instruction': {   'description': 'executes '
#                                                              'instruction '
#                                                              'given by the '
#                                                              'ASCII string '
#                                                              'parameter '
#                                                              "'command'. If "
#                                                              'return data size '
#                                                              'is greater than '
#                                                              '0, it reads the '
#                                                              'response and '
#                                                              'returns the '
#                                                              'response. Return '
#                                                              'Data Size - in '
#                                                              'bytes - 1 ASCII '
#                                                              'character = 1 '
#                                                              'Byte.',
#                                               'input': {   'properties': {   'command': {   'type': 'string'},
#                                                                              'return_data_size': {   'default': 0,
#                                                                                                      'minimum': 0,
#                                                                                                      'type': 'integer'}},
#                                                            'required': [   'command'],
#                                                            'type': 'object'},
#                                               'output': {'type': 'string'},
#                                               'synchronous': True},
#                    'exit': {   'description': 'Stop serving the object. This '
#                                               'method can only be called '
#                                               'remotely',
#                                'synchronous': True},
#                    'get_analogue_offset': {   'description': 'analogue offset '
#                                                              'for a voltage '
#                                                              'range and '
#                                                              'coupling',
#                                               'input': {   'properties': {   'coupling': {   'enum': [   'AC',
#                                                                                                          'DC'],
#                                                                                              'type': 'string'},
#                                                                              'voltage_range': {   'enum': [   '10mV',
#                                                                                                               '20mV',
#                                                                                                               '50mV',
#                                                                                                               '100mV',
#                                                                                                               '200mV',
#                                                                                                               '500mV',
#                                                                                                               '1V',
#                                                                                                               '2V',
#                                                                                                               '5V',
#                                                                                                               '10V',
#                                                                                                               '20V',
#                                                                                                               '50V',
#                                                                                                               'MAX_RANGES'],
#                                                                                                   'type': 'string'}},
#                                                            'type': 'object'},
#                                               'output': {   'items': {   'type': 'number'},
#                                                             'maxItems': 2,
#                                                             'minItems': 2,
#                                                             'type': 'array'},
#                                               'synchronous': True},
#                    'get_mixed_content_data': {'synchronous': True},
#                    'get_non_remote_number_prop': {'synchronous': True},
#                    'get_serialized_data': {'synchronous': True},
#                    'get_thing_model': {   'description': 'generate the [Thing '
#                                                          'Model](https://www.w3.org/TR/wot-thing-description11/#introduction-tm) '
#                                                          'of the object. The '
#                                                          'model is a JSON that '
#                                                          'describes the '
#                                                          "object's properties, "
#                                                          'actions, events and '
#                                                          'their metadata, '
#                                                          'without the protocol '
#                                                          'information. The '
#                                                          'model can be used by '
#                                                          'a client to '
#                                                          'understand the '
#                                                          "object's "
#                                                          'capabilities.',
#                                           'input': {   'properties': {   'ignore_errors': {   'default': False,
#                                                                                               'type': 'boolean'},
#                                                                          'skip_names': {   'default': [   ],
#                                                                                            'items': {   'type': 'string'},
#                                                                                            'type': 'array'}},
#                                                        'type': 'object'},
#                                           'synchronous': True},
#                    'get_transports': {'synchronous': True},
#                    'ping': {   'description': 'ping the `Thing` to see if it '
#                                               'is alive. Ping successful when '
#                                               'action succeeds with no return '
#                                               'value and no timeout or '
#                                               'exception raised on the client '
#                                               'side.',
#                                'synchronous': True},
#                    'print_props': {'synchronous': True},
#                    'push_events': {   'input': {   'properties': {   'event_name': {   'default': 'test_event',
#                                                                                        'type': 'string'},
#                                                                      'total_number_of_events': {   'default': 100,
#                                                                                                    'type': 'integer'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel': {   'description': 'Set the parameter for a '
#                                                      'channel. '
#                                                      'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                       'input': {   'properties': {   'bw_limiter': {   'enum': [   'full',
#                                                                                                    '20MHz'],
#                                                                                        'type': 'string'},
#                                                                      'channel': {   'enum': [   'A',
#                                                                                                 'B',
#                                                                                                 'C',
#                                                                                                 'D'],
#                                                                                     'type': 'string'},
#                                                                      'coupling': {   'enum': [   'AC',
#                                                                                                  'DC'],
#                                                                                      'type': 'string'},
#                                                                      'enabled': {   'type': 'boolean'},
#                                                                      'offset': {   'type': 'number'},
#                                                                      'voltage_range': {   'enum': [   '10mV',
#                                                                                                       '20mV',
#                                                                                                       '50mV',
#                                                                                                       '100mV',
#                                                                                                       '200mV',
#                                                                                                       '500mV',
#                                                                                                       '1V',
#                                                                                                       '2V',
#                                                                                                       '5V',
#                                                                                                       '10V',
#                                                                                                       '20V',
#                                                                                                       '50V',
#                                                                                                       'MAX_RANGES'],
#                                                                                           'type': 'string'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel_pydantic': {   'description': 'Set the '
#                                                               'parameter for a '
#                                                               'channel. '
#                                                               'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                                'input': {   'properties': {   'bw_limiter': {   'default': 'full',
#                                                                                                 'enum': [   'full',
#                                                                                                             '20MHz'],
#                                                                                                 'type': 'string'},
#                                                                               'channel': {   'enum': [   'A',
#                                                                                                          'B',
#                                                                                                          'C',
#                                                                                                          'D'],
#                                                                                              'type': 'string'},
#                                                                               'coupling': {   'default': 'DC_1M',
#                                                                                               'enum': [   'AC',
#                                                                                                           'DC'],
#                                                                                               'type': 'string'},
#                                                                               'enabled': {   'default': True,
#                                                                                              'type': 'boolean'},
#                                                                               'offset': {   'default': 0,
#                                                                                             'type': 'number'},
#                                                                               'v_range': {   'default': '2V',
#                                                                                              'enum': [   '10mV',
#                                                                                                          '20mV',
#                                                                                                          '50mV',
#                                                                                                          '100mV',
#                                                                                                          '200mV',
#                                                                                                          '500mV',
#                                                                                                          '1V',
#                                                                                                          '2V',
#                                                                                                          '5V',
#                                                                                                          '10V',
#                                                                                                          '20V',
#                                                                                                          '50V',
#                                                                                                          'MAX_RANGES'],
#                                                                                              'type': 'string'}},
#                                                             'required': [   'channel'],
#                                                             'type': 'object'},
#                                                'synchronous': True},
#                    'set_non_remote_number_prop': {'synchronous': True},
#                    'set_sensor_model': {   'description': 'Set the attached '
#                                                           'sensor to the meter '
#                                                           'under control. '
#                                                           'Sensor should be '
#                                                           'defined as a class '
#                                                           'and added to the '
#                                                           'AllowedSensors '
#                                                           'dict.',
#                                            'input': {   'enum': [   'QE25LP-S-MB',
#                                                                     'QE12LP-S-MB-QED-D0'],
#                                                         'type': 'string'},
#                                            'synchronous': True},
#                    'set_sensor_model_pydantic': {   'description': 'Set the '
#                                                                    'attached '
#                                                                    'sensor to '
#                                                                    'the meter '
#                                                                    'under '
#                                                                    'control. '
#                                                                    'Sensor '
#                                                                    'should be '
#                                                                    'defined as '
#                                                                    'a class '
#                                                                    'and added '
#                                                                    'to the '
#                                                                    'AllowedSensors '
#                                                                    'dict.',
#                                                     'input': {   'properties': {   'value': {   'enum': [   'QE25LP-S-MB',
#                                                                                                             'QE12LP-S-MB-QED-D0'],
#                                                                                                 'type': 'string'}},
#                                                                  'required': [   'value'],
#                                                                  'type': 'object'},
#                                                     'synchronous': True},
#                    'sleep': {'synchronous': True},
#                    'start_acquisition': {   'description': 'Start acquisition '
#                                                            'of energy '
#                                                            'measurements.',
#                                             'input': {   'properties': {   'max_count': {   'exclusiveMinimum': 0,
#                                                                                             'type': 'integer'}},
#                                                          'required': [   'max_count'],
#                                                          'type': 'object'},
#                                             'synchronous': True}},
#     'context': ['https://www.w3.org/2022/wot/td/v1.1'],
#     'events': {   'data_point_event': {   'data': {   'properties': {   'energy': {   'type': 'number'},
#                                                                         'timestamp': {   'type': 'string'}},
#                                                       'required': [   'timestamp',
#                                                                       'energy'],
#                                                       'type': 'object'},
#                                           'description': 'Event raised when a '
#                                                          'new data point is '
#                                                          'available'},
#                   'test_binary_payload_event': {   'description': 'test event '
#                                                                   'with binary '
#                                                                   'payload'},
#                   'test_event': {   'description': 'test event with arbitrary '
#                                                    'payload'},
#                   'test_event_with_json_schema': {   'description': 'test '
#                                                                     'event '
#                                                                     'with '
#                                                                     'schema '
#                                                                     'validation'},
#                   'test_event_with_pydantic_schema': {   'description': 'test '
#                                                                         'event '
#                                                                         'with '
#                                                                         'pydantic '
#                                                                         'schema '
#                                                                         'validation'},
#                   'test_mixed_content_payload_event': {   'description': 'test '
#                                                                          'event '
#                                                                          'with '
#                                                                          'mixed '
#                                                                          'content '
#                                                                          'payload'}},
#     'id': 'example-test',
#     'properties': {   'db_commit_number_prop': {   'default': 0,
#                                                    'description': 'A fully '
#                                                                   'editable '
#                                                                   'number '
#                                                                   'property to '
#                                                                   'check '
#                                                                   'commits to '
#                                                                   'db on write '
#                                                                   'operations',
#                                                    'type': 'number'},
#                       'db_init_int_prop': {   'default': 1,
#                                               'description': 'An integer '
#                                                              'property to '
#                                                              'check '
#                                                              'initialization '
#                                                              'from db',
#                                               'type': 'integer'},
#                       'db_persist_selector_prop': {   'default': 'a',
#                                                       'description': 'A '
#                                                                      'selector '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'persistence '
#                                                                      'to db on '
#                                                                      'write '
#                                                                      'operations',
#                                                       'enum': [   'a',
#                                                                   'b',
#                                                                   'c',
#                                                                   1],
#                                                       'oneOf': [   {   'type': 'string'},
#                                                                    {   'type': 'integer'}]},
#                       'deletable_class_prop': {   'default': 100,
#                                                   'description': 'deletable '
#                                                                  'class '
#                                                                  'property '
#                                                                  'with custom '
#                                                                  'deleter',
#                                                   'type': 'number'},
#                       'int_prop': {   'default': 5,
#                                       'description': 'An integer property with '
#                                                      'step and bounds '
#                                                      'constraints to check RW',
#                                       'maximum': 100,
#                                       'minimum': 0,
#                                       'multipleOf': 2,
#                                       'type': 'integer'},
#                       'json_schema_prop': {   'description': 'A property with '
#                                                              'a json schema to '
#                                                              'check RW',
#                                               'oneOf': [   {'type': 'null'},
#                                                            {   'maxLength': 10,
#                                                                'minLength': 1,
#                                                                'pattern': '^[a-z]+$',
#                                                                'type': 'string'}]},
#                       'managed_class_prop': {   'default': 0.0,
#                                                 'description': '(managed) '
#                                                                'class property '
#                                                                'with custom '
#                                                                'getter/setter',
#                                                 'type': 'number'},
#                       'not_a_class_prop': {   'default': 43,
#                                               'description': 'test property '
#                                                              'with '
#                                                              'class_member=False',
#                                               'type': 'number'},
#                       'number_prop': {   'default': 1,
#                                          'description': 'A fully editable '
#                                                         'number property',
#                                          'type': 'number'},
#                       'observable_list_prop': {   'description': 'An '
#                                                                  'observable '
#                                                                  'list '
#                                                                  'property to '
#                                                                  'check '
#                                                                  'observable '
#                                                                  'events on '
#                                                                  'write '
#                                                                  'operations',
#                                                   'observable': True,
#                                                   'oneOf': [   {   'type': 'array'},
#                                                                {   'type': 'null'}]},
#                       'observable_readonly_prop': {   'default': 0,
#                                                       'description': 'An '
#                                                                      'observable '
#                                                                      'readonly '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'observable '
#                                                                      'events '
#                                                                      'on read '
#                                                                      'operations',
#                                                       'observable': True,
#                                                       'readOnly': True,
#                                                       'type': 'number'},
#                       'pydantic_prop': {   'description': 'A property with a '
#                                                           'pydantic model to '
#                                                           'check RW',
#                                            'oneOf': [   {'type': 'null'},
#                                                         {   'properties': {   'bar': {   'type': 'integer'},
#                                                                               'foo': {   'type': 'string'},
#                                                                               'foo_bar': {   'type': 'number'}},
#                                                             'required': [   'foo',
#                                                                             'bar',
#                                                                             'foo_bar'],
#                                                             'type': 'object'}]},
#                       'pydantic_simple_prop': {   'description': 'A property '
#                                                                  'with a '
#                                                                  'simple '
#                                                                  'pydantic '
#                                                                  'model to '
#                                                                  'check RW',
#                                                   'oneOf': [   {'type': 'null'},
#                                                                {   'type': 'integer'}]},
#                       'readonly_class_prop': {   'default': '',
#                                                  'description': 'read-only '
#                                                                 'class '
#                                                                 'property',
#                                                  'readOnly': True,
#                                                  'type': 'string'},
#                       'selector_prop': {   'default': 'a',
#                                            'description': 'A selector property '
#                                                           'to check RW',
#                                            'enum': ['a', 'b', 'c', 1],
#                                            'oneOf': [   {'type': 'string'},
#                                                         {'type': 'integer'}]},
#                       'simple_class_prop': {   'default': 42,
#                                                'description': 'simple class '
#                                                               'property with '
#                                                               'default value',
#                                                'type': 'number'},
#                       'sleeping_prop': {   'default': 0,
#                                            'description': 'A property that '
#                                                           'sleeps for 10 '
#                                                           'seconds on read '
#                                                           'operations',
#                                            'observable': True,
#                                            'readOnly': True,
#                                            'type': 'number'},
#                       'string_prop': {   'default': 'hello',
#                                          'description': 'A string property '
#                                                         'with a regex '
#                                                         'constraint to check '
#                                                         'value errors',
#                                          'pattern': '^[a-z]+',
#                                          'type': 'string'},
#                       'total_number_of_events': {   'default': 100,
#                                                     'description': 'Total '
#                                                                    'number of '
#                                                                    'events '
#                                                                    'pushed',
#                                                     'minimum': 1,
#                                                     'type': 'number'}},
#     'title': 'TestThing'}

# %%
from pprint import pprint
pprint(thing.rpc_server.get_thing_description(thing, protocol='INPROC', ignore_errors=True), indent=4)
# Out:
# ERROR    - 2025-09-06T18:59:26:294 - example-test - Error while generating schema for base_property - WoT schema generator for this descriptor/property is not implemented. name base_property & type <class 'hololinked.core.property.Property'>
# {   'actions': {   'action_echo': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'invokeaction'}],
#                                       'synchronous': True},
#                    'execute_instruction': {   'description': 'executes '
#                                                              'instruction '
#                                                              'given by the '
#                                                              'ASCII string '
#                                                              'parameter '
#                                                              "'command'. If "
#                                                              'return data size '
#                                                              'is greater than '
#                                                              '0, it reads the '
#                                                              'response and '
#                                                              'returns the '
#                                                              'response. Return '
#                                                              'Data Size - in '
#                                                              'bytes - 1 ASCII '
#                                                              'character = 1 '
#                                                              'Byte.',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'invokeaction'}],
#                                               'input': {   'properties': {   'command': {   'type': 'string'},
#                                                                              'return_data_size': {   'default': 0,
#                                                                                                      'minimum': 0,
#                                                                                                      'type': 'integer'}},
#                                                            'required': [   'command'],
#                                                            'type': 'object'},
#                                               'output': {'type': 'string'},
#                                               'synchronous': True},
#                    'exit': {   'description': 'Stop serving the object. This '
#                                               'method can only be called '
#                                               'remotely',
#                                'forms': [   {   'contentType': 'application/json',
#                                                 'href': 'inproc://example-test',
#                                                 'op': 'invokeaction'}],
#                                'synchronous': True},
#                    'get_analogue_offset': {   'description': 'analogue offset '
#                                                              'for a voltage '
#                                                              'range and '
#                                                              'coupling',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'invokeaction'}],
#                                               'input': {   'properties': {   'coupling': {   'enum': [   'AC',
#                                                                                                          'DC'],
#                                                                                              'type': 'string'},
#                                                                              'voltage_range': {   'enum': [   '10mV',
#                                                                                                               '20mV',
#                                                                                                               '50mV',
#                                                                                                               '100mV',
#                                                                                                               '200mV',
#                                                                                                               '500mV',
#                                                                                                               '1V',
#                                                                                                               '2V',
#                                                                                                               '5V',
#                                                                                                               '10V',
#                                                                                                               '20V',
#                                                                                                               '50V',
#                                                                                                               'MAX_RANGES'],
#                                                                                                   'type': 'string'}},
#                                                            'type': 'object'},
#                                               'output': {   'items': {   'type': 'number'},
#                                                             'maxItems': 2,
#                                                             'minItems': 2,
#                                                             'type': 'array'},
#                                               'synchronous': True},
#                    'get_mixed_content_data': {   'forms': [   {   'contentType': 'application/json',
#                                                                   'href': 'inproc://example-test',
#                                                                   'op': 'invokeaction'}],
#                                                  'synchronous': True},
#                    'get_non_remote_number_prop': {   'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'inproc://example-test',
#                                                                       'op': 'invokeaction'}],
#                                                      'synchronous': True},
#                    'get_serialized_data': {   'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'invokeaction'}],
#                                               'synchronous': True},
#                    'get_thing_model': {   'description': 'generate the [Thing '
#                                                          'Model](https://www.w3.org/TR/wot-thing-description11/#introduction-tm) '
#                                                          'of the object. The '
#                                                          'model is a JSON that '
#                                                          'describes the '
#                                                          "object's properties, "
#                                                          'actions, events and '
#                                                          'their metadata, '
#                                                          'without the protocol '
#                                                          'information. The '
#                                                          'model can be used by '
#                                                          'a client to '
#                                                          'understand the '
#                                                          "object's "
#                                                          'capabilities.',
#                                           'forms': [   {   'contentType': 'application/json',
#                                                            'href': 'inproc://example-test',
#                                                            'op': 'invokeaction'}],
#                                           'input': {   'properties': {   'ignore_errors': {   'default': False,
#                                                                                               'type': 'boolean'},
#                                                                          'skip_names': {   'default': [   ],
#                                                                                            'items': {   'type': 'string'},
#                                                                                            'type': 'array'}},
#                                                        'type': 'object'},
#                                           'synchronous': True},
#                    'get_transports': {   'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'invokeaction'}],
#                                          'synchronous': True},
#                    'ping': {   'description': 'ping the `Thing` to see if it '
#                                               'is alive. Ping successful when '
#                                               'action succeeds with no return '
#                                               'value and no timeout or '
#                                               'exception raised on the client '
#                                               'side.',
#                                'forms': [   {   'contentType': 'application/json',
#                                                 'href': 'inproc://example-test',
#                                                 'op': 'invokeaction'}],
#                                'synchronous': True},
#                    'print_props': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'invokeaction'}],
#                                       'synchronous': True},
#                    'push_events': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'invokeaction'}],
#                                       'input': {   'properties': {   'event_name': {   'default': 'test_event',
#                                                                                        'type': 'string'},
#                                                                      'total_number_of_events': {   'default': 100,
#                                                                                                    'type': 'integer'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel': {   'description': 'Set the parameter for a '
#                                                      'channel. '
#                                                      'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                       'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'invokeaction'}],
#                                       'input': {   'properties': {   'bw_limiter': {   'enum': [   'full',
#                                                                                                    '20MHz'],
#                                                                                        'type': 'string'},
#                                                                      'channel': {   'enum': [   'A',
#                                                                                                 'B',
#                                                                                                 'C',
#                                                                                                 'D'],
#                                                                                     'type': 'string'},
#                                                                      'coupling': {   'enum': [   'AC',
#                                                                                                  'DC'],
#                                                                                      'type': 'string'},
#                                                                      'enabled': {   'type': 'boolean'},
#                                                                      'offset': {   'type': 'number'},
#                                                                      'voltage_range': {   'enum': [   '10mV',
#                                                                                                       '20mV',
#                                                                                                       '50mV',
#                                                                                                       '100mV',
#                                                                                                       '200mV',
#                                                                                                       '500mV',
#                                                                                                       '1V',
#                                                                                                       '2V',
#                                                                                                       '5V',
#                                                                                                       '10V',
#                                                                                                       '20V',
#                                                                                                       '50V',
#                                                                                                       'MAX_RANGES'],
#                                                                                           'type': 'string'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel_pydantic': {   'description': 'Set the '
#                                                               'parameter for a '
#                                                               'channel. '
#                                                               'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                                'forms': [   {   'contentType': 'application/json',
#                                                                 'href': 'inproc://example-test',
#                                                                 'op': 'invokeaction'}],
#                                                'input': {   'properties': {   'bw_limiter': {   'default': 'full',
#                                                                                                 'enum': [   'full',
#                                                                                                             '20MHz'],
#                                                                                                 'type': 'string'},
#                                                                               'channel': {   'enum': [   'A',
#                                                                                                          'B',
#                                                                                                          'C',
#                                                                                                          'D'],
#                                                                                              'type': 'string'},
#                                                                               'coupling': {   'default': 'DC_1M',
#                                                                                               'enum': [   'AC',
#                                                                                                           'DC'],
#                                                                                               'type': 'string'},
#                                                                               'enabled': {   'default': True,
#                                                                                              'type': 'boolean'},
#                                                                               'offset': {   'default': 0,
#                                                                                             'type': 'number'},
#                                                                               'v_range': {   'default': '2V',
#                                                                                              'enum': [   '10mV',
#                                                                                                          '20mV',
#                                                                                                          '50mV',
#                                                                                                          '100mV',
#                                                                                                          '200mV',
#                                                                                                          '500mV',
#                                                                                                          '1V',
#                                                                                                          '2V',
#                                                                                                          '5V',
#                                                                                                          '10V',
#                                                                                                          '20V',
#                                                                                                          '50V',
#                                                                                                          'MAX_RANGES'],
#                                                                                              'type': 'string'}},
#                                                             'required': [   'channel'],
#                                                             'type': 'object'},
#                                                'synchronous': True},
#                    'set_non_remote_number_prop': {   'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'inproc://example-test',
#                                                                       'op': 'invokeaction'}],
#                                                      'synchronous': True},
#                    'set_sensor_model': {   'description': 'Set the attached '
#                                                           'sensor to the meter '
#                                                           'under control. '
#                                                           'Sensor should be '
#                                                           'defined as a class '
#                                                           'and added to the '
#                                                           'AllowedSensors '
#                                                           'dict.',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'invokeaction'}],
#                                            'input': {   'enum': [   'QE25LP-S-MB',
#                                                                     'QE12LP-S-MB-QED-D0'],
#                                                         'type': 'string'},
#                                            'synchronous': True},
#                    'set_sensor_model_pydantic': {   'description': 'Set the '
#                                                                    'attached '
#                                                                    'sensor to '
#                                                                    'the meter '
#                                                                    'under '
#                                                                    'control. '
#                                                                    'Sensor '
#                                                                    'should be '
#                                                                    'defined as '
#                                                                    'a class '
#                                                                    'and added '
#                                                                    'to the '
#                                                                    'AllowedSensors '
#                                                                    'dict.',
#                                                     'forms': [   {   'contentType': 'application/json',
#                                                                      'href': 'inproc://example-test',
#                                                                      'op': 'invokeaction'}],
#                                                     'input': {   'properties': {   'value': {   'enum': [   'QE25LP-S-MB',
#                                                                                                             'QE12LP-S-MB-QED-D0'],
#                                                                                                 'type': 'string'}},
#                                                                  'required': [   'value'],
#                                                                  'type': 'object'},
#                                                     'synchronous': True},
#                    'sleep': {   'forms': [   {   'contentType': 'application/json',
#                                                  'href': 'inproc://example-test',
#                                                  'op': 'invokeaction'}],
#                                 'synchronous': True},
#                    'start_acquisition': {   'description': 'Start acquisition '
#                                                            'of energy '
#                                                            'measurements.',
#                                             'forms': [   {   'contentType': 'application/json',
#                                                              'href': 'inproc://example-test',
#                                                              'op': 'invokeaction'}],
#                                             'input': {   'properties': {   'max_count': {   'exclusiveMinimum': 0,
#                                                                                             'type': 'integer'}},
#                                                          'required': [   'max_count'],
#                                                          'type': 'object'},
#                                             'synchronous': True}},
#     'context': ['https://www.w3.org/2022/wot/td/v1.1'],
#     'events': {   'data_point_event': {   'data': {   'properties': {   'energy': {   'type': 'number'},
#                                                                         'timestamp': {   'type': 'string'}},
#                                                       'required': [   'timestamp',
#                                                                       'energy'],
#                                                       'type': 'object'},
#                                           'description': 'Event raised when a '
#                                                          'new data point is '
#                                                          'available',
#                                           'forms': [   {   'contentType': 'application/json',
#                                                            'href': 'inproc://example-test/event-publisher',
#                                                            'op': 'subscribeevent'}]},
#                   'test_binary_payload_event': {   'description': 'test event '
#                                                                   'with binary '
#                                                                   'payload',
#                                                    'forms': [   {   'contentType': 'application/json',
#                                                                     'href': 'inproc://example-test/event-publisher',
#                                                                     'op': 'subscribeevent'}]},
#                   'test_event': {   'description': 'test event with arbitrary '
#                                                    'payload',
#                                     'forms': [   {   'contentType': 'application/json',
#                                                      'href': 'inproc://example-test/event-publisher',
#                                                      'op': 'subscribeevent'}]},
#                   'test_event_with_json_schema': {   'description': 'test '
#                                                                     'event '
#                                                                     'with '
#                                                                     'schema '
#                                                                     'validation',
#                                                      'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'inproc://example-test/event-publisher',
#                                                                       'op': 'subscribeevent'}]},
#                   'test_event_with_pydantic_schema': {   'description': 'test '
#                                                                         'event '
#                                                                         'with '
#                                                                         'pydantic '
#                                                                         'schema '
#                                                                         'validation',
#                                                          'forms': [   {   'contentType': 'application/json',
#                                                                           'href': 'inproc://example-test/event-publisher',
#                                                                           'op': 'subscribeevent'}]},
#                   'test_mixed_content_payload_event': {   'description': 'test '
#                                                                          'event '
#                                                                          'with '
#                                                                          'mixed '
#                                                                          'content '
#                                                                          'payload',
#                                                           'forms': [   {   'contentType': 'application/json',
#                                                                            'href': 'inproc://example-test/event-publisher',
#                                                                            'op': 'subscribeevent'}]}},
#     'id': 'example-test',
#     'properties': {   'db_commit_number_prop': {   'default': 0,
#                                                    'description': 'A fully '
#                                                                   'editable '
#                                                                   'number '
#                                                                   'property to '
#                                                                   'check '
#                                                                   'commits to '
#                                                                   'db on write '
#                                                                   'operations',
#                                                    'forms': [   {   'contentType': 'application/json',
#                                                                     'href': 'inproc://example-test',
#                                                                     'op': 'readproperty'},
#                                                                 {   'contentType': 'application/json',
#                                                                     'href': 'inproc://example-test',
#                                                                     'op': 'writeproperty'}],
#                                                    'type': 'number'},
#                       'db_init_int_prop': {   'default': 1,
#                                               'description': 'An integer '
#                                                              'property to '
#                                                              'check '
#                                                              'initialization '
#                                                              'from db',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'writeproperty'}],
#                                               'type': 'integer'},
#                       'db_persist_selector_prop': {   'default': 'a',
#                                                       'description': 'A '
#                                                                      'selector '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'persistence '
#                                                                      'to db on '
#                                                                      'write '
#                                                                      'operations',
#                                                       'enum': [   'a',
#                                                                   'b',
#                                                                   'c',
#                                                                   1],
#                                                       'forms': [   {   'contentType': 'application/json',
#                                                                        'href': 'inproc://example-test',
#                                                                        'op': 'readproperty'},
#                                                                    {   'contentType': 'application/json',
#                                                                        'href': 'inproc://example-test',
#                                                                        'op': 'writeproperty'}],
#                                                       'oneOf': [   {   'type': 'string'},
#                                                                    {   'type': 'integer'}]},
#                       'deletable_class_prop': {   'default': 100,
#                                                   'description': 'deletable '
#                                                                  'class '
#                                                                  'property '
#                                                                  'with custom '
#                                                                  'deleter',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'writeproperty'}],
#                                                   'type': 'number'},
#                       'int_prop': {   'default': 5,
#                                       'description': 'An integer property with '
#                                                      'step and bounds '
#                                                      'constraints to check RW',
#                                       'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'readproperty'},
#                                                    {   'contentType': 'application/json',
#                                                        'href': 'inproc://example-test',
#                                                        'op': 'writeproperty'}],
#                                       'maximum': 100,
#                                       'minimum': 0,
#                                       'multipleOf': 2,
#                                       'type': 'integer'},
#                       'json_schema_prop': {   'description': 'A property with '
#                                                              'a json schema to '
#                                                              'check RW',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'writeproperty'}],
#                                               'oneOf': [   {'type': 'null'},
#                                                            {   'maxLength': 10,
#                                                                'minLength': 1,
#                                                                'pattern': '^[a-z]+$',
#                                                                'type': 'string'}]},
#                       'managed_class_prop': {   'default': 0.0,
#                                                 'description': '(managed) '
#                                                                'class property '
#                                                                'with custom '
#                                                                'getter/setter',
#                                                 'forms': [   {   'contentType': 'application/json',
#                                                                  'href': 'inproc://example-test',
#                                                                  'op': 'readproperty'},
#                                                              {   'contentType': 'application/json',
#                                                                  'href': 'inproc://example-test',
#                                                                  'op': 'writeproperty'}],
#                                                 'type': 'number'},
#                       'not_a_class_prop': {   'default': 43,
#                                               'description': 'test property '
#                                                              'with '
#                                                              'class_member=False',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'inproc://example-test',
#                                                                'op': 'writeproperty'}],
#                                               'type': 'number'},
#                       'number_prop': {   'default': 1,
#                                          'description': 'A fully editable '
#                                                         'number property',
#                                          'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'readproperty'},
#                                                       {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'writeproperty'}],
#                                          'type': 'number'},
#                       'observable_list_prop': {   'description': 'An '
#                                                                  'observable '
#                                                                  'list '
#                                                                  'property to '
#                                                                  'check '
#                                                                  'observable '
#                                                                  'events on '
#                                                                  'write '
#                                                                  'operations',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'writeproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test/event-publisher',
#                                                                    'op': 'observeproperty'}],
#                                                   'observable': True,
#                                                   'oneOf': [   {   'type': 'array'},
#                                                                {   'type': 'null'}]},
#                       'observable_readonly_prop': {   'default': 0,
#                                                       'description': 'An '
#                                                                      'observable '
#                                                                      'readonly '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'observable '
#                                                                      'events '
#                                                                      'on read '
#                                                                      'operations',
#                                                       'forms': [   {   'contentType': 'application/json',
#                                                                        'href': 'inproc://example-test',
#                                                                        'op': 'readproperty'},
#                                                                    {   'contentType': 'application/json',
#                                                                        'href': 'inproc://example-test/event-publisher',
#                                                                        'op': 'observeproperty'}],
#                                                       'observable': True,
#                                                       'readOnly': True,
#                                                       'type': 'number'},
#                       'pydantic_prop': {   'description': 'A property with a '
#                                                           'pydantic model to '
#                                                           'check RW',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'writeproperty'}],
#                                            'oneOf': [   {'type': 'null'},
#                                                         {   'properties': {   'bar': {   'type': 'integer'},
#                                                                               'foo': {   'type': 'string'},
#                                                                               'foo_bar': {   'type': 'number'}},
#                                                             'required': [   'foo',
#                                                                             'bar',
#                                                                             'foo_bar'],
#                                                             'type': 'object'}]},
#                       'pydantic_simple_prop': {   'description': 'A property '
#                                                                  'with a '
#                                                                  'simple '
#                                                                  'pydantic '
#                                                                  'model to '
#                                                                  'check RW',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'inproc://example-test',
#                                                                    'op': 'writeproperty'}],
#                                                   'oneOf': [   {'type': 'null'},
#                                                                {   'type': 'integer'}]},
#                       'readonly_class_prop': {   'default': '',
#                                                  'description': 'read-only '
#                                                                 'class '
#                                                                 'property',
#                                                  'forms': [   {   'contentType': 'application/json',
#                                                                   'href': 'inproc://example-test',
#                                                                   'op': 'readproperty'}],
#                                                  'readOnly': True,
#                                                  'type': 'string'},
#                       'selector_prop': {   'default': 'a',
#                                            'description': 'A selector property '
#                                                           'to check RW',
#                                            'enum': ['a', 'b', 'c', 1],
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'writeproperty'}],
#                                            'oneOf': [   {'type': 'string'},
#                                                         {'type': 'integer'}]},
#                       'simple_class_prop': {   'default': 42,
#                                                'description': 'simple class '
#                                                               'property with '
#                                                               'default value',
#                                                'forms': [   {   'contentType': 'application/json',
#                                                                 'href': 'inproc://example-test',
#                                                                 'op': 'readproperty'},
#                                                             {   'contentType': 'application/json',
#                                                                 'href': 'inproc://example-test',
#                                                                 'op': 'writeproperty'}],
#                                                'type': 'number'},
#                       'sleeping_prop': {   'default': 0,
#                                            'description': 'A property that '
#                                                           'sleeps for 10 '
#                                                           'seconds on read '
#                                                           'operations',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'inproc://example-test/event-publisher',
#                                                             'op': 'observeproperty'}],
#                                            'observable': True,
#                                            'readOnly': True,
#                                            'type': 'number'},
#                       'string_prop': {   'default': 'hello',
#                                          'description': 'A string property '
#                                                         'with a regex '
#                                                         'constraint to check '
#                                                         'value errors',
#                                          'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'readproperty'},
#                                                       {   'contentType': 'application/json',
#                                                           'href': 'inproc://example-test',
#                                                           'op': 'writeproperty'}],
#                                          'pattern': '^[a-z]+',
#                                          'type': 'string'},
#                       'total_number_of_events': {   'default': 100,
#                                                     'description': 'Total '
#                                                                    'number of '
#                                                                    'events '
#                                                                    'pushed',
#                                                     'forms': [   {   'contentType': 'application/json',
#                                                                      'href': 'inproc://example-test',
#                                                                      'op': 'readproperty'},
#                                                                  {   'contentType': 'application/json',
#                                                                      'href': 'inproc://example-test',
#                                                                      'op': 'writeproperty'}],
#                                                     'minimum': 1,
#                                                     'type': 'number'}},
#     'title': 'TestThing'}

# %%
from hololinked.client.factory import ClientFactory

object_proxy = ClientFactory.zmq(server_id="example-test", thing_id="example-test", protocol="IPC", ignore_TD_errors=True)
pprint(object_proxy.td, indent=4)
# Out:
# INFO     - 2025-09-06T19:14:22:745 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: ROUTER with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test.ipc & identity: example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab|sync and connected
# INFO     - 2025-09-06T19:14:22:746 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - sent Handshake to server 'example-test'
# INFO     - 2025-09-06T19:14:22:749 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - client 'example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab|sync' handshook with server 'example-test'
# INFO     - 2025-09-06T19:14:22:754 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: ROUTER with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test.ipc & identity: example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab|async and connected
# INFO     - 2025-09-06T19:14:22:789 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|observable_list_prop|sync and connected
# INFO     - 2025-09-06T19:14:22:794 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|observable_list_prop|async and connected
# INFO     - 2025-09-06T19:14:22:800 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|observable_readonly_prop|sync and connected
# INFO     - 2025-09-06T19:14:22:806 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|observable_readonly_prop|async and connected
# INFO     - 2025-09-06T19:14:22:812 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|sleeping_prop|sync and connected
# INFO     - 2025-09-06T19:14:22:818 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|sleeping_prop|async and connected
# INFO     - 2025-09-06T19:14:22:824 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|data_point_event|sync and connected
# INFO     - 2025-09-06T19:14:22:829 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|data_point_event|async and connected
# INFO     - 2025-09-06T19:14:22:833 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_binary_payload_event|sync and connected
# INFO     - 2025-09-06T19:14:22:838 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_binary_payload_event|async and connected
# INFO     - 2025-09-06T19:14:22:842 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event|sync and connected
# INFO     - 2025-09-06T19:14:22:845 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event|async and connected
# INFO     - 2025-09-06T19:14:22:849 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event_with_json_schema|sync and connected
# INFO     - 2025-09-06T19:14:22:853 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event_with_json_schema|async and connected
# INFO     - 2025-09-06T19:14:22:858 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event_with_pydantic_schema|sync and connected
# INFO     - 2025-09-06T19:14:22:862 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_event_with_pydantic_schema|async and connected
# INFO     - 2025-09-06T19:14:22:865 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_mixed_content_payload_event|sync and connected
# INFO     - 2025-09-06T19:14:22:869 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - created socket type: SUB with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test\event-publisher.ipc & identity: example-test|test_mixed_content_payload_event|async and connected
# {   'actions': {   'action_echo': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'invokeaction'}],
#                                       'synchronous': True},
#                    'execute_instruction': {   'description': 'executes '
#                                                              'instruction '
#                                                              'given by the '
#                                                              'ASCII string '
#                                                              'parameter '
#                                                              "'command'. If "
#                                                              'return data size '
#                                                              'is greater than '
#                                                              '0, it reads the '
#                                                              'response and '
#                                                              'returns the '
#                                                              'response. Return '
#                                                              'Data Size - in '
#                                                              'bytes - 1 ASCII '
#                                                              'character = 1 '
#                                                              'Byte.',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'invokeaction'}],
#                                               'input': {   'properties': {   'command': {   'type': 'string'},
#                                                                              'return_data_size': {   'default': 0,
#                                                                                                      'minimum': 0,
#                                                                                                      'type': 'integer'}},
#                                                            'required': [   'command'],
#                                                            'type': 'object'},
#                                               'output': {'type': 'string'},
#                                               'synchronous': True},
#                    'exit': {   'description': 'Stop serving the object. This '
#                                               'method can only be called '
#                                               'remotely',
#                                'forms': [   {   'contentType': 'application/json',
#                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                 'op': 'invokeaction'}],
#                                'synchronous': True},
#                    'get_analogue_offset': {   'description': 'analogue offset '
#                                                              'for a voltage '
#                                                              'range and '
#                                                              'coupling',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'invokeaction'}],
#                                               'input': {   'properties': {   'coupling': {   'enum': [   'AC',
#                                                                                                          'DC'],
#                                                                                              'type': 'string'},
#                                                                              'voltage_range': {   'enum': [   '10mV',
#                                                                                                               '20mV',
#                                                                                                               '50mV',
#                                                                                                               '100mV',
#                                                                                                               '200mV',
#                                                                                                               '500mV',
#                                                                                                               '1V',
#                                                                                                               '2V',
#                                                                                                               '5V',
#                                                                                                               '10V',
#                                                                                                               '20V',
#                                                                                                               '50V',
#                                                                                                               'MAX_RANGES'],
#                                                                                                   'type': 'string'}},
#                                                            'type': 'object'},
#                                               'output': {   'items': {   'type': 'number'},
#                                                             'maxItems': 2,
#                                                             'minItems': 2,
#                                                             'type': 'array'},
#                                               'synchronous': True},
#                    'get_mixed_content_data': {   'forms': [   {   'contentType': 'application/json',
#                                                                   'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                   'op': 'invokeaction'}],
#                                                  'synchronous': True},
#                    'get_non_remote_number_prop': {   'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                       'op': 'invokeaction'}],
#                                                      'synchronous': True},
#                    'get_serialized_data': {   'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'invokeaction'}],
#                                               'synchronous': True},
#                    'get_thing_model': {   'description': 'generate the [Thing '
#                                                          'Model](https://www.w3.org/TR/wot-thing-description11/#introduction-tm) '
#                                                          'of the object. The '
#                                                          'model is a JSON that '
#                                                          'describes the '
#                                                          "object's properties, "
#                                                          'actions, events and '
#                                                          'their metadata, '
#                                                          'without the protocol '
#                                                          'information. The '
#                                                          'model can be used by '
#                                                          'a client to '
#                                                          'understand the '
#                                                          "object's "
#                                                          'capabilities.',
#                                           'forms': [   {   'contentType': 'application/json',
#                                                            'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                            'op': 'invokeaction'}],
#                                           'input': {   'properties': {   'ignore_errors': {   'default': False,
#                                                                                               'type': 'boolean'},
#                                                                          'skip_names': {   'default': [   ],
#                                                                                            'items': {   'type': 'string'},
#                                                                                            'type': 'array'}},
#                                                        'type': 'object'},
#                                           'synchronous': True},
#                    'get_transports': {   'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'invokeaction'}],
#                                          'synchronous': True},
#                    'ping': {   'description': 'ping the `Thing` to see if it '
#                                               'is alive. Ping successful when '
#                                               'action succeeds with no return '
#                                               'value and no timeout or '
#                                               'exception raised on the client '
#                                               'side.',
#                                'forms': [   {   'contentType': 'application/json',
#                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                 'op': 'invokeaction'}],
#                                'synchronous': True},
#                    'print_props': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'invokeaction'}],
#                                       'synchronous': True},
#                    'push_events': {   'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'invokeaction'}],
#                                       'input': {   'properties': {   'event_name': {   'default': 'test_event',
#                                                                                        'type': 'string'},
#                                                                      'total_number_of_events': {   'default': 100,
#                                                                                                    'type': 'integer'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel': {   'description': 'Set the parameter for a '
#                                                      'channel. '
#                                                      'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                       'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'invokeaction'}],
#                                       'input': {   'properties': {   'bw_limiter': {   'enum': [   'full',
#                                                                                                    '20MHz'],
#                                                                                        'type': 'string'},
#                                                                      'channel': {   'enum': [   'A',
#                                                                                                 'B',
#                                                                                                 'C',
#                                                                                                 'D'],
#                                                                                     'type': 'string'},
#                                                                      'coupling': {   'enum': [   'AC',
#                                                                                                  'DC'],
#                                                                                      'type': 'string'},
#                                                                      'enabled': {   'type': 'boolean'},
#                                                                      'offset': {   'type': 'number'},
#                                                                      'voltage_range': {   'enum': [   '10mV',
#                                                                                                       '20mV',
#                                                                                                       '50mV',
#                                                                                                       '100mV',
#                                                                                                       '200mV',
#                                                                                                       '500mV',
#                                                                                                       '1V',
#                                                                                                       '2V',
#                                                                                                       '5V',
#                                                                                                       '10V',
#                                                                                                       '20V',
#                                                                                                       '50V',
#                                                                                                       'MAX_RANGES'],
#                                                                                           'type': 'string'}},
#                                                    'type': 'object'},
#                                       'synchronous': True},
#                    'set_channel_pydantic': {   'description': 'Set the '
#                                                               'parameter for a '
#                                                               'channel. '
#                                                               'https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#                                                'forms': [   {   'contentType': 'application/json',
#                                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                 'op': 'invokeaction'}],
#                                                'input': {   'properties': {   'bw_limiter': {   'default': 'full',
#                                                                                                 'enum': [   'full',
#                                                                                                             '20MHz'],
#                                                                                                 'type': 'string'},
#                                                                               'channel': {   'enum': [   'A',
#                                                                                                          'B',
#                                                                                                          'C',
#                                                                                                          'D'],
#                                                                                              'type': 'string'},
#                                                                               'coupling': {   'default': 'DC_1M',
#                                                                                               'enum': [   'AC',
#                                                                                                           'DC'],
#                                                                                               'type': 'string'},
#                                                                               'enabled': {   'default': True,
#                                                                                              'type': 'boolean'},
#                                                                               'offset': {   'default': 0,
#                                                                                             'type': 'number'},
#                                                                               'v_range': {   'default': '2V',
#                                                                                              'enum': [   '10mV',
#                                                                                                          '20mV',
#                                                                                                          '50mV',
#                                                                                                          '100mV',
#                                                                                                          '200mV',
#                                                                                                          '500mV',
#                                                                                                          '1V',
#                                                                                                          '2V',
#                                                                                                          '5V',
#                                                                                                          '10V',
#                                                                                                          '20V',
#                                                                                                          '50V',
#                                                                                                          'MAX_RANGES'],
#                                                                                              'type': 'string'}},
#                                                             'required': [   'channel'],
#                                                             'type': 'object'},
#                                                'synchronous': True},
#                    'set_non_remote_number_prop': {   'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                       'op': 'invokeaction'}],
#                                                      'synchronous': True},
#                    'set_sensor_model': {   'description': 'Set the attached '
#                                                           'sensor to the meter '
#                                                           'under control. '
#                                                           'Sensor should be '
#                                                           'defined as a class '
#                                                           'and added to the '
#                                                           'AllowedSensors '
#                                                           'dict.',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'invokeaction'}],
#                                            'input': {   'enum': [   'QE25LP-S-MB',
#                                                                     'QE12LP-S-MB-QED-D0'],
#                                                         'type': 'string'},
#                                            'synchronous': True},
#                    'set_sensor_model_pydantic': {   'description': 'Set the '
#                                                                    'attached '
#                                                                    'sensor to '
#                                                                    'the meter '
#                                                                    'under '
#                                                                    'control. '
#                                                                    'Sensor '
#                                                                    'should be '
#                                                                    'defined as '
#                                                                    'a class '
#                                                                    'and added '
#                                                                    'to the '
#                                                                    'AllowedSensors '
#                                                                    'dict.',
#                                                     'forms': [   {   'contentType': 'application/json',
#                                                                      'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                      'op': 'invokeaction'}],
#                                                     'input': {   'properties': {   'value': {   'enum': [   'QE25LP-S-MB',
#                                                                                                             'QE12LP-S-MB-QED-D0'],
#                                                                                                 'type': 'string'}},
#                                                                  'required': [   'value'],
#                                                                  'type': 'object'},
#                                                     'synchronous': True},
#                    'sleep': {   'forms': [   {   'contentType': 'application/json',
#                                                  'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                  'op': 'invokeaction'}],
#                                 'synchronous': True},
#                    'start_acquisition': {   'description': 'Start acquisition '
#                                                            'of energy '
#                                                            'measurements.',
#                                             'forms': [   {   'contentType': 'application/json',
#                                                              'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                              'op': 'invokeaction'}],
#                                             'input': {   'properties': {   'max_count': {   'exclusiveMinimum': 0,
#                                                                                             'type': 'integer'}},
#                                                          'required': [   'max_count'],
#                                                          'type': 'object'},
#                                             'synchronous': True}},
#     'context': ['https://www.w3.org/2022/wot/td/v1.1'],
#     'events': {   'data_point_event': {   'data': {   'properties': {   'energy': {   'type': 'number'},
#                                                                         'timestamp': {   'type': 'string'}},
#                                                       'required': [   'timestamp',
#                                                                       'energy'],
#                                                       'type': 'object'},
#                                           'description': 'Event raised when a '
#                                                          'new data point is '
#                                                          'available',
#                                           'forms': [   {   'contentType': 'application/json',
#                                                            'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                            'op': 'subscribeevent'}]},
#                   'test_binary_payload_event': {   'description': 'test event '
#                                                                   'with binary '
#                                                                   'payload',
#                                                    'forms': [   {   'contentType': 'application/json',
#                                                                     'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                     'op': 'subscribeevent'}]},
#                   'test_event': {   'description': 'test event with arbitrary '
#                                                    'payload',
#                                     'forms': [   {   'contentType': 'application/json',
#                                                      'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                      'op': 'subscribeevent'}]},
#                   'test_event_with_json_schema': {   'description': 'test '
#                                                                     'event '
#                                                                     'with '
#                                                                     'schema '
#                                                                     'validation',
#                                                      'forms': [   {   'contentType': 'application/json',
#                                                                       'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                       'op': 'subscribeevent'}]},
#                   'test_event_with_pydantic_schema': {   'description': 'test '
#                                                                         'event '
#                                                                         'with '
#                                                                         'pydantic '
#                                                                         'schema '
#                                                                         'validation',
#                                                          'forms': [   {   'contentType': 'application/json',
#                                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                           'op': 'subscribeevent'}]},
#                   'test_mixed_content_payload_event': {   'description': 'test '
#                                                                          'event '
#                                                                          'with '
#                                                                          'mixed '
#                                                                          'content '
#                                                                          'payload',
#                                                           'forms': [   {   'contentType': 'application/json',
#                                                                            'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                            'op': 'subscribeevent'}]}},
#     'id': 'example-test',
#     'properties': {   'db_commit_number_prop': {   'default': 0,
#                                                    'description': 'A fully '
#                                                                   'editable '
#                                                                   'number '
#                                                                   'property to '
#                                                                   'check '
#                                                                   'commits to '
#                                                                   'db on write '
#                                                                   'operations',
#                                                    'forms': [   {   'contentType': 'application/json',
#                                                                     'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                     'op': 'readproperty'},
#                                                                 {   'contentType': 'application/json',
#                                                                     'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                     'op': 'writeproperty'}],
#                                                    'type': 'number'},
#                       'db_init_int_prop': {   'default': 1,
#                                               'description': 'An integer '
#                                                              'property to '
#                                                              'check '
#                                                              'initialization '
#                                                              'from db',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'writeproperty'}],
#                                               'type': 'integer'},
#                       'db_persist_selector_prop': {   'default': 'a',
#                                                       'description': 'A '
#                                                                      'selector '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'persistence '
#                                                                      'to db on '
#                                                                      'write '
#                                                                      'operations',
#                                                       'enum': [   'a',
#                                                                   'b',
#                                                                   'c',
#                                                                   1],
#                                                       'forms': [   {   'contentType': 'application/json',
#                                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                        'op': 'readproperty'},
#                                                                    {   'contentType': 'application/json',
#                                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                        'op': 'writeproperty'}],
#                                                       'oneOf': [   {   'type': 'string'},
#                                                                    {   'type': 'integer'}]},
#                       'deletable_class_prop': {   'default': 100,
#                                                   'description': 'deletable '
#                                                                  'class '
#                                                                  'property '
#                                                                  'with custom '
#                                                                  'deleter',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'writeproperty'}],
#                                                   'type': 'number'},
#                       'int_prop': {   'default': 5,
#                                       'description': 'An integer property with '
#                                                      'step and bounds '
#                                                      'constraints to check RW',
#                                       'forms': [   {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'readproperty'},
#                                                    {   'contentType': 'application/json',
#                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                        'op': 'writeproperty'}],
#                                       'maximum': 100,
#                                       'minimum': 0,
#                                       'multipleOf': 2,
#                                       'type': 'integer'},
#                       'json_schema_prop': {   'description': 'A property with '
#                                                              'a json schema to '
#                                                              'check RW',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'writeproperty'}],
#                                               'oneOf': [   {'type': 'null'},
#                                                            {   'maxLength': 10,
#                                                                'minLength': 1,
#                                                                'pattern': '^[a-z]+$',
#                                                                'type': 'string'}]},
#                       'managed_class_prop': {   'default': 0.0,
#                                                 'description': '(managed) '
#                                                                'class property '
#                                                                'with custom '
#                                                                'getter/setter',
#                                                 'forms': [   {   'contentType': 'application/json',
#                                                                  'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                  'op': 'readproperty'},
#                                                              {   'contentType': 'application/json',
#                                                                  'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                  'op': 'writeproperty'}],
#                                                 'type': 'number'},
#                       'not_a_class_prop': {   'default': 43,
#                                               'description': 'test property '
#                                                              'with '
#                                                              'class_member=False',
#                                               'forms': [   {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'readproperty'},
#                                                            {   'contentType': 'application/json',
#                                                                'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                'op': 'writeproperty'}],
#                                               'type': 'number'},
#                       'number_prop': {   'default': 1,
#                                          'description': 'A fully editable '
#                                                         'number property',
#                                          'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'readproperty'},
#                                                       {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'writeproperty'}],
#                                          'type': 'number'},
#                       'observable_list_prop': {   'description': 'An '
#                                                                  'observable '
#                                                                  'list '
#                                                                  'property to '
#                                                                  'check '
#                                                                  'observable '
#                                                                  'events on '
#                                                                  'write '
#                                                                  'operations',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'writeproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                    'op': 'observeproperty'}],
#                                                   'observable': True,
#                                                   'oneOf': [   {   'type': 'array'},
#                                                                {   'type': 'null'}]},
#                       'observable_readonly_prop': {   'default': 0,
#                                                       'description': 'An '
#                                                                      'observable '
#                                                                      'readonly '
#                                                                      'property '
#                                                                      'to check '
#                                                                      'observable '
#                                                                      'events '
#                                                                      'on read '
#                                                                      'operations',
#                                                       'forms': [   {   'contentType': 'application/json',
#                                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                        'op': 'readproperty'},
#                                                                    {   'contentType': 'application/json',
#                                                                        'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                                        'op': 'observeproperty'}],
#                                                       'observable': True,
#                                                       'readOnly': True,
#                                                       'type': 'number'},
#                       'pydantic_prop': {   'description': 'A property with a '
#                                                           'pydantic model to '
#                                                           'check RW',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'writeproperty'}],
#                                            'oneOf': [   {'type': 'null'},
#                                                         {   'properties': {   'bar': {   'type': 'integer'},
#                                                                               'foo': {   'type': 'string'},
#                                                                               'foo_bar': {   'type': 'number'}},
#                                                             'required': [   'foo',
#                                                                             'bar',
#                                                                             'foo_bar'],
#                                                             'type': 'object'}]},
#                       'pydantic_simple_prop': {   'description': 'A property '
#                                                                  'with a '
#                                                                  'simple '
#                                                                  'pydantic '
#                                                                  'model to '
#                                                                  'check RW',
#                                                   'forms': [   {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'readproperty'},
#                                                                {   'contentType': 'application/json',
#                                                                    'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                    'op': 'writeproperty'}],
#                                                   'oneOf': [   {'type': 'null'},
#                                                                {   'type': 'integer'}]},
#                       'readonly_class_prop': {   'default': '',
#                                                  'description': 'read-only '
#                                                                 'class '
#                                                                 'property',
#                                                  'forms': [   {   'contentType': 'application/json',
#                                                                   'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                   'op': 'readproperty'}],
#                                                  'readOnly': True,
#                                                  'type': 'string'},
#                       'selector_prop': {   'default': 'a',
#                                            'description': 'A selector property '
#                                                           'to check RW',
#                                            'enum': ['a', 'b', 'c', 1],
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'writeproperty'}],
#                                            'oneOf': [   {'type': 'string'},
#                                                         {'type': 'integer'}]},
#                       'simple_class_prop': {   'default': 42,
#                                                'description': 'simple class '
#                                                               'property with '
#                                                               'default value',
#                                                'forms': [   {   'contentType': 'application/json',
#                                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                 'op': 'readproperty'},
#                                                             {   'contentType': 'application/json',
#                                                                 'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                 'op': 'writeproperty'}],
#                                                'type': 'number'},
#                       'sleeping_prop': {   'default': 0,
#                                            'description': 'A property that '
#                                                           'sleeps for 10 '
#                                                           'seconds on read '
#                                                           'operations',
#                                            'forms': [   {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                             'op': 'readproperty'},
#                                                         {   'contentType': 'application/json',
#                                                             'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test\\event-publisher.ipc',
#                                                             'op': 'observeproperty'}],
#                                            'observable': True,
#                                            'readOnly': True,
#                                            'type': 'number'},
#                       'string_prop': {   'default': 'hello',
#                                          'description': 'A string property '
#                                                         'with a regex '
#                                                         'constraint to check '
#                                                         'value errors',
#                                          'forms': [   {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'readproperty'},
#                                                       {   'contentType': 'application/json',
#                                                           'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                           'op': 'writeproperty'}],
#                                          'pattern': '^[a-z]+',
#                                          'type': 'string'},
#                       'total_number_of_events': {   'default': 100,
#                                                     'description': 'Total '
#                                                                    'number of '
#                                                                    'events '
#                                                                    'pushed',
#                                                     'forms': [   {   'contentType': 'application/json',
#                                                                      'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                      'op': 'readproperty'},
#                                                                  {   'contentType': 'application/json',
#                                                                      'href': 'ipc://C:\\Users\\vvign\\AppData\\Local\\Temp\\hololinked\\example-test.ipc',
#                                                                      'op': 'writeproperty'}],
#                                                     'minimum': 1,
#                                                     'type': 'number'}},
#     'title': 'TestThing'}
# INFO     - 2025-09-06T19:14:22:894 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - sent Handshake to server 'example-test'
# INFO     - 2025-09-06T19:14:22:896 - example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab - client 'example-test|example-test|IPC|57fcbb74-faa9-4b42-8019-f261883914ab|async' handshook with server 'example-test'

# %%
TestThing.get_analogue_offset.to_affordance().json()
# Out:
# {'description': 'analogue offset for a voltage range and coupling',
#  'input': {'type': 'object',
#   'properties': {'voltage_range': {'type': 'string',
#     'enum': ['10mV',
#      '20mV',
#      '50mV',
#      '100mV',
#      '200mV',
#      '500mV',
#      '1V',
#      '2V',
#      '5V',
#      '10V',
#      '20V',
#      '50V',
#      'MAX_RANGES']},
#    'coupling': {'type': 'string', 'enum': ['AC', 'DC']}}},
#  'output': {'type': 'array',
#   'minItems': 2,
#   'maxItems': 2,
#   'items': {'type': 'number'}},
#  'synchronous': True}

# %%
TestThing.set_channel.to_affordance().json()
# Out:
# {'description': 'Set the parameter for a channel. https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#  'input': {'type': 'object',
#   'properties': {'channel': {'type': 'string', 'enum': ['A', 'B', 'C', 'D']},
#    'enabled': {'type': 'boolean'},
#    'voltage_range': {'type': 'string',
#     'enum': ['10mV',
#      '20mV',
#      '50mV',
#      '100mV',
#      '200mV',
#      '500mV',
#      '1V',
#      '2V',
#      '5V',
#      '10V',
#      '20V',
#      '50V',
#      'MAX_RANGES']},
#    'offset': {'type': 'number'},
#    'coupling': {'type': 'string', 'enum': ['AC', 'DC']},
#    'bw_limiter': {'type': 'string', 'enum': ['full', '20MHz']}}},
#  'synchronous': True}

# %%
TestThing.set_sensor_model.to_affordance().json()
# Out:
# {'description': 'Set the attached sensor to the meter under control. Sensor should be defined as a class and added to the AllowedSensors dict.',
#  'input': {'type': 'string', 'enum': ['QE25LP-S-MB', 'QE12LP-S-MB-QED-D0']},
#  'synchronous': True}

# %%
TestThing.set_channel_pydantic.to_affordance().json()
# Out:
# {'description': 'Set the parameter for a channel. https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#  'input': {'properties': {'channel': {'enum': ['A', 'B', 'C', 'D'],
#     'type': 'string'},
#    'enabled': {'default': True, 'type': 'boolean'},
#    'v_range': {'default': '2V',
#     'enum': ['10mV',
#      '20mV',
#      '50mV',
#      '100mV',
#      '200mV',
#      '500mV',
#      '1V',
#      '2V',
#      '5V',
#      '10V',
#      '20V',
#      '50V',
#      'MAX_RANGES'],
#     'type': 'string'},
#    'offset': {'default': 0, 'type': 'number'},
#    'coupling': {'default': 'DC_1M', 'enum': ['AC', 'DC'], 'type': 'string'},
#    'bw_limiter': {'default': 'full',
#     'enum': ['full', '20MHz'],
#     'type': 'string'}},
#   'required': ['channel'],
#   'type': 'object'},
#  'synchronous': True}

# %%
from hololinked.utils import get_input_model_from_signature

get_input_model_from_signature(TestThing.set_channel_pydantic.obj)
# Out:
# hololinked.utils.set_channel_pydantic_input

# %%
TestThing.start_acquisition.to_affordance().json()
# Out:
# {'description': 'Start acquisition of energy measurements.',
#  'input': {'properties': {'max_count': {'exclusiveMinimum': 0,
#     'type': 'integer'}},
#   'required': ['max_count'],
#   'type': 'object'},
#  'synchronous': True}

# %%
TestThing.execute_instruction.to_affordance().json()
# Out:
# {'description': "executes instruction given by the ASCII string parameter 'command'. If return data size is greater than 0, it reads the response and returns the response. Return Data Size - in bytes - 1 ASCII character = 1 Byte.",
#  'input': {'properties': {'command': {'type': 'string'},
#    'return_data_size': {'default': 0, 'minimum': 0, 'type': 'integer'}},
#   'required': ['command'],
#   'type': 'object'},
#  'output': {'format': 'binary', 'type': 'string'},
#  'synchronous': True}

# %%
TestThing.data_point_event.to_affordance().json()
# Out:
# {'description': 'Event raised when a new data point is available',
#  'data': {'type': 'object',
#   'properties': {'timestamp': {'type': 'string'},
#    'energy': {'type': 'number'}},
#   'required': ['timestamp', 'energy']}}

# %%
from hololinked.client import ClientFactory

object_proxy = ClientFactory.http("http://localhost:9000/example-test/resources/wot-td", ignore_TD_errors=True)
object_proxy_zmq = ClientFactory.zmq(server_id="example-test-server", thing_id="example-test", access_point="IPC", ignore_TD_errors=True)
object_proxy.td
# Out:
# INFO     - 2025-10-04T09:04:47:988 - example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297 - created socket type: ROUTER with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test-server.ipc & identity: example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297|sync and connected
# INFO     - 2025-10-04T09:04:47:990 - example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297 - sent Handshake to server 'example-test-server'
# INFO     - 2025-10-04T09:04:47:991 - example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297 - client 'example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297|sync' handshook with server 'example-test-server'
# INFO     - 2025-10-04T09:04:47:997 - example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297 - created socket type: ROUTER with address: ipc://C:\Users\vvign\AppData\Local\Temp\hololinked\example-test-server.ipc & identity: example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297|async and connected
# {'context': ['https://www.w3.org/2022/wot/td/v1.1'],
#  'id': 'http://127.0.0.1:9000/example-test',
#  'title': 'TestThing',
#  'properties': {'db_commit_number_prop': {'description': 'A fully editable number property to check commits to db on write operations',
#    'default': 0,
#    'type': 'number',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/db-commit-number-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/db-commit-number-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'db_init_int_prop': {'description': 'An integer property to check initialization from db',
#    'default': 1,
#    'type': 'integer',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/db-init-int-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/x-pickle'},
#     {'href': 'http://127.0.0.1:9000/example-test/db-init-int-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/x-pickle'}]},
#   'db_persist_selector_prop': {'description': 'A selector property to check persistence to db on write operations',
#    'default': 'a',
#    'oneOf': [{'type': 'string'}, {'type': 'integer'}],
#    'enum': ['a', 'b', 'c', 1],
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/db-persist-selector-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/db-persist-selector-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'deletable_class_prop': {'description': 'deletable class property with custom deleter',
#    'default': 100,
#    'type': 'number',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/deletable-class-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/deletable-class-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'int_prop': {'description': 'An integer property with step and bounds constraints to check RW',
#    'default': 5,
#    'type': 'integer',
#    'minimum': 0,
#    'maximum': 100,
#    'multipleOf': 2,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/int-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/int-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'json_schema_prop': {'description': 'A property with a json schema to check RW',
#    'oneOf': [{'type': 'null'},
#     {'type': 'string',
#      'minLength': 1,
#      'maxLength': 10,
#      'pattern': '^[a-z]+$'}],
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/json-schema-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/json-schema-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'managed_class_prop': {'description': '(managed) class property with custom getter/setter',
#    'default': 0.0,
#    'type': 'number',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/managed-class-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/managed-class-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'not_a_class_prop': {'description': 'test property with class_member=False',
#    'default': 43,
#    'type': 'number',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/not-a-class-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/not-a-class-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'number_prop': {'description': 'A fully editable number property',
#    'default': 1,
#    'type': 'number',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/number-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/number-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'observable_list_prop': {'description': 'An observable list property to check observable events on write operations',
#    'oneOf': [{'type': 'array'}, {'type': 'null'}],
#    'observable': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/observable-list-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/observable-list-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/observable-list-prop/change-event',
#      'op': 'observeproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json',
#      'subprotocol': 'sse'}]},
#   'observable_readonly_prop': {'description': 'An observable readonly property to check observable events on read operations',
#    'default': 0,
#    'readOnly': True,
#    'type': 'number',
#    'observable': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/observable-readonly-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/observable-readonly-prop/change-event',
#      'op': 'observeproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json',
#      'subprotocol': 'sse'}]},
#   'pydantic_prop': {'description': 'A property with a pydantic model to check RW',
#    'oneOf': [{'type': 'null'},
#     {'properties': {'foo': {'type': 'string'},
#       'bar': {'type': 'integer'},
#       'foo_bar': {'type': 'number'}},
#      'required': ['foo', 'bar', 'foo_bar'],
#      'type': 'object'}],
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/pydantic-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/pydantic-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'pydantic_simple_prop': {'description': 'A property with a simple pydantic model to check RW',
#    'oneOf': [{'type': 'null'}, {'type': 'integer'}],
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/pydantic-simple-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/pydantic-simple-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'readonly_class_prop': {'description': 'read-only class property',
#    'default': '',
#    'readOnly': True,
#    'type': 'string',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/readonly-class-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'}]},
#   'selector_prop': {'description': 'A selector property to check RW',
#    'default': 'a',
#    'oneOf': [{'type': 'string'}, {'type': 'integer'}],
#    'enum': ['a', 'b', 'c', 1],
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/selector-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/selector-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'simple_class_prop': {'description': 'simple class property with default value',
#    'default': 42,
#    'type': 'number',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/simple-class-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/simple-class-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'sleeping_prop': {'description': 'A property that sleeps for 10 seconds on read operations',
#    'default': 0,
#    'readOnly': True,
#    'type': 'number',
#    'observable': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/sleeping-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/sleeping-prop/change-event',
#      'op': 'observeproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json',
#      'subprotocol': 'sse'}]},
#   'string_prop': {'description': 'A string property with a regex constraint to check value errors',
#    'default': 'hello',
#    'type': 'string',
#    'pattern': '^[a-z]+',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/string-prop',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/string-prop',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]},
#   'total_number_of_events': {'description': 'Total number of events pushed',
#    'default': 100,
#    'type': 'number',
#    'minimum': 1,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/total-number-of-events',
#      'op': 'readproperty',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json'},
#     {'href': 'http://127.0.0.1:9000/example-test/total-number-of-events',
#      'op': 'writeproperty',
#      'htv:methodName': 'PUT',
#      'contentType': 'application/json'}]}},
#  'actions': {'action_echo': {'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/action-echo',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'execute_instruction': {'description': "executes instruction given by the ASCII string parameter 'command'. If return data size is greater than 0, it reads the response and returns the response. Return Data Size - in bytes - 1 ASCII character = 1 Byte.",
#    'input': {'properties': {'command': {'type': 'string'},
#      'return_data_size': {'default': 0, 'minimum': 0, 'type': 'integer'}},
#     'required': ['command'],
#     'type': 'object'},
#    'output': {'type': 'string'},
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/execute-instruction',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'exit': {'description': 'Stop serving the object. This method usually needs to be called remotely',
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/exit',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'get_analogue_offset': {'description': 'analogue offset for a voltage range and coupling',
#    'input': {'type': 'object',
#     'properties': {'voltage_range': {'type': 'string',
#       'enum': ['10mV',
#        '20mV',
#        '50mV',
#        '100mV',
#        '200mV',
#        '500mV',
#        '1V',
#        '2V',
#        '5V',
#        '10V',
#        '20V',
#        '50V',
#        'MAX_RANGES']},
#      'coupling': {'type': 'string', 'enum': ['AC', 'DC']}}},
#    'output': {'type': 'array',
#     'minItems': 2,
#     'maxItems': 2,
#     'items': {'type': 'number'}},
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/get-analogue-offset',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'get_mixed_content_data': {'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/get-mixed-content-data',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'get_non_remote_number_prop': {'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/get-non-remote-number-prop',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/msgpack'}]},
#   'get_serialized_data': {'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/get-serialized-data',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'get_thing_model': {'description': "generate the [Thing Model](https://www.w3.org/TR/wot-thing-description11/#introduction-tm) of the object. The model is a JSON that describes the object's properties, actions, events and their metadata, without the protocol information. The model can be used by a client to understand the object's capabilities.",
#    'input': {'properties': {'ignore_errors': {'default': False,
#       'type': 'boolean'},
#      'skip_names': {'default': [],
#       'items': {'type': 'string'},
#       'type': 'array'}},
#     'type': 'object'},
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/resources/wot-tm',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'get_transports': {'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/get-transports',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'ping': {'description': 'ping to see if it is alive. Successful when action succeeds with no return value and no timeout or exception raised on the client side.',
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/ping',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'print_props': {'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/print-props',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'push_events': {'input': {'properties': {'event_name': {'default': 'test_event',
#       'type': 'string'},
#      'total_number_of_events': {'default': 100, 'type': 'integer'}},
#     'type': 'object'},
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/push-events',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'set_channel': {'description': 'Set the parameter for a channel. https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#    'input': {'type': 'object',
#     'properties': {'channel': {'type': 'string', 'enum': ['A', 'B', 'C', 'D']},
#      'enabled': {'type': 'boolean'},
#      'voltage_range': {'type': 'string',
#       'enum': ['10mV',
#        '20mV',
#        '50mV',
#        '100mV',
#        '200mV',
#        '500mV',
#        '1V',
#        '2V',
#        '5V',
#        '10V',
#        '20V',
#        '50V',
#        'MAX_RANGES']},
#      'offset': {'type': 'number'},
#      'coupling': {'type': 'string', 'enum': ['AC', 'DC']},
#      'bw_limiter': {'type': 'string', 'enum': ['full', '20MHz']}}},
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/set-channel',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'set_channel_pydantic': {'description': 'Set the parameter for a channel. https://www.picotech.com/download/manuals/picoscope-6000-series-a-api-programmers-guide.pdf',
#    'input': {'properties': {'channel': {'enum': ['A', 'B', 'C', 'D'],
#       'type': 'string'},
#      'enabled': {'default': True, 'type': 'boolean'},
#      'v_range': {'default': '2V',
#       'enum': ['10mV',
#        '20mV',
#        '50mV',
#        '100mV',
#        '200mV',
#        '500mV',
#        '1V',
#        '2V',
#        '5V',
#        '10V',
#        '20V',
#        '50V',
#        'MAX_RANGES'],
#       'type': 'string'},
#      'offset': {'default': 0, 'type': 'number'},
#      'coupling': {'default': 'DC_1M', 'enum': ['AC', 'DC'], 'type': 'string'},
#      'bw_limiter': {'default': 'full',
#       'enum': ['full', '20MHz'],
#       'type': 'string'}},
#     'required': ['channel'],
#     'type': 'object'},
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/set-channel-pydantic',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'set_non_remote_number_prop': {'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/set-non-remote-number-prop',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/msgpack'}]},
#   'set_sensor_model': {'description': 'Set the attached sensor to the meter under control. Sensor should be defined as a class and added to the AllowedSensors dict.',
#    'input': {'type': 'string', 'enum': ['QE25LP-S-MB', 'QE12LP-S-MB-QED-D0']},
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/set-sensor-model',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'set_sensor_model_pydantic': {'description': 'Set the attached sensor to the meter under control. Sensor should be defined as a class and added to the AllowedSensors dict.',
#    'input': {'properties': {'value': {'enum': ['QE25LP-S-MB',
#        'QE12LP-S-MB-QED-D0'],
#       'type': 'string'}},
#     'required': ['value'],
#     'type': 'object'},
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/set-sensor-model-pydantic',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'sleep': {'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/sleep',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]},
#   'start_acquisition': {'description': 'Start acquisition of energy measurements.',
#    'input': {'properties': {'max_count': {'exclusiveMinimum': 0,
#       'type': 'integer'}},
#     'required': ['max_count'],
#     'type': 'object'},
#    'synchronous': True,
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/start-acquisition',
#      'op': 'invokeaction',
#      'htv:methodName': 'POST',
#      'contentType': 'application/json'}]}},
#  'events': {'data_point_event': {'description': 'Event raised when a new data point is available',
#    'data': {'type': 'object',
#     'properties': {'timestamp': {'type': 'string'},
#      'energy': {'type': 'number'}},
#     'required': ['timestamp', 'energy']},
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/data-point-event',
#      'op': 'subscribeevent',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json',
#      'subprotocol': 'sse'}]},
#   'test_binary_payload_event': {'description': 'test event with binary payload',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/test-binary-payload-event',
#      'op': 'subscribeevent',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json',
#      'subprotocol': 'sse'}]},
#   'test_event': {'description': 'test event with arbitrary payload',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/test-event',
#      'op': 'subscribeevent',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json',
#      'subprotocol': 'sse'}]},
#   'test_event_with_json_schema': {'description': 'test event with schema validation',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/test-event-with-json-schema',
#      'op': 'subscribeevent',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json',
#      'subprotocol': 'sse'}]},
#   'test_event_with_pydantic_schema': {'description': 'test event with pydantic schema validation',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/test-event-with-pydantic-schema',
#      'op': 'subscribeevent',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json',
#      'subprotocol': 'sse'}]},
#   'test_mixed_content_payload_event': {'description': 'test event with mixed content payload',
#    'forms': [{'href': 'http://127.0.0.1:9000/example-test/test-mixed-content-payload-event',
#      'op': 'subscribeevent',
#      'htv:methodName': 'GET',
#      'contentType': 'application/json',
#      'subprotocol': 'sse'}]}},
#  'securityDefinitions': {'nosec': {'scheme': 'nosec',
#    'description': 'currently no security scheme supported - use cookie auth directly on hololinked.server.HTTPServer object'}},
#  'security': ['nosec']}
# INFO     - 2025-10-04T09:04:48:029 - example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297 - sent Handshake to server 'example-test-server'
# INFO     - 2025-10-04T09:04:48:030 - example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297 - client 'example-test-server|example-test|IPC|9d199fbf-f1db-41de-89e7-964650bb8297|async' handshook with server 'example-test-server'

# %%
import threading 
import asyncio

def cb(value):
    print("event0", threading.get_ident(), value.data)

def cb1(value):
    print("event1 ", threading.get_ident(), value.data)

def cb2(value):
    print("event2 ", threading.get_ident(), value.data)

async def async_cb1(value):
    print("event1 ", asyncio.current_task().get_name(), value.data)

async def async_cb2(value):
    print("event2 ", asyncio.current_task().get_name(), value.data)

# object_proxy.subscribe_event("test_event", cb)
# object_proxy.subscribe_event("test_event", [cb1, cb2], concurrent=True)
# object_proxy.subscribe_event("test_event", [async_cb1, async_cb2], asynch=True)
object_proxy.subscribe_event("test_event", [async_cb1, async_cb2], asynch=True, concurrent=True)
# Out:
# INFO     - 2025-09-07T10:45:05:257 - example-test|example-test|tcp://localhost:60000|c81e5234-3549-406c-8b4a-50ed721055b6 - created socket type: SUB with address: tcp://LAPTOP-TUBBGPB8:60001 & identity: example-test|test_event|async|2e5a03fa and connected
# event1  Task-22 test data
# event2  Task-23 test data
# event1  Task-24 test data
# event2  Task-25 test data
# event1  Task-26 test data
# event2  Task-27 test data
# event1  Task-28 test data
# event2  Task-29 test data
# event1  Task-30 test data
# event2  Task-31 test data
# event1  Task-32 test data
# event2  Task-33 test data
# event1  Task-34 test data
# event2  Task-35 test data
# event1  Task-36 test data
# event2  Task-37 test data
# event1  Task-38 test data
# event2  Task-39 test data
# event1  Task-40 test data
# event2  Task-41 test data
# event1  Task-42 test data
# event2  Task-43 test data
# event1  Task-44 test data
# event2  Task-45 test data
# event1  Task-46 test data
# event2  Task-47 test data
# event1  Task-48 test data
# event2  Task-49 test data
# event1  Task-50 test data
# event2  Task-51 test data
# event1  Task-52 test data
# event2  Task-53 test data
# event1  Task-54 test data
# event2  Task-55 test data
# event1  Task-56 test data
# event2  Task-57 test data
# event1  Task-58 test data
# event2  Task-59 test data
# event1  Task-60 test data
# event2  Task-61 test data
# event1  Task-62 test data
# event2  Task-63 test data
# event1  Task-64 test data
# event2  Task-65 test data
# event1  Task-66 test data
# event2  Task-67 test data
# event1  Task-68 test data
# event2  Task-69 test data
# event1  Task-70 test data
# event2  Task-71 test data
# event1  Task-72 test data
# event2  Task-73 test data
# event1  Task-74 test data
# event2  Task-75 test data
# event1  Task-76 test data
# event2  Task-77 test data
# event1  Task-78 test data
# event2  Task-79 test data
# event1  Task-80 test data
# event2  Task-81 test data
# event1  Task-82 test data
# event2  Task-83 test data
# event1  Task-84 test data
# event2  Task-85 test data
# event1  Task-86 test data
# event2  Task-87 test data
# event1  Task-88 test data
# event2  Task-89 test data
# event1  Task-90 test data
# event2  Task-91 test data
# event1  Task-92 test data
# event2  Task-93 test data
# event1  Task-94 test data
# event2  Task-95 test data
# event1  Task-96 test data
# event2  Task-97 test data
# event1  Task-98 test data
# event2  Task-99 test data
# event1  Task-100 test data
# event2  Task-101 test data
# event1  Task-102 test data
# event2  Task-103 test data
# event1  Task-104 test data
# event2  Task-105 test data
# event1  Task-106 test data
# event2  Task-107 test data
# event1  Task-108 test data
# event2  Task-109 test data
# event1  Task-110 test data
# event2  Task-111 test data
# event1  Task-112 test data
# event2  Task-113 test data
# event1  Task-114 test data
# event2  Task-115 test data
# event1  Task-116 test data
# event2  Task-117 test data
# event1  Task-118 test data
# event2  Task-119 test data
# event1  Task-120 test data
# event2  Task-121 test data
# event1  Task-122 test data
# event2  Task-123 test data
# event1  Task-124 test data
# event2  Task-125 test data
# event1  Task-126 test data
# event2  Task-127 test data
# event1  Task-128 test data
# event2  Task-129 test data
# event1  Task-130 test data
# event2  Task-131 test data
# event1  Task-132 test data
# event2  Task-133 test data
# event1  Task-134 test data
# event2  Task-135 test data
# event1  Task-136 test data
# event2  Task-137 test data
# event1  Task-138 test data
# event2  Task-139 test data
# event1  Task-140 test data
# event2  Task-141 test data
# event1  Task-142 test data
# event2  Task-143 test data
# event1  Task-144 test data
# event2  Task-145 test data
# event1  Task-146 test data
# event2  Task-147 test data
# event1  Task-148 test data
# event2  Task-149 test data
# event1  Task-150 test data
# event2  Task-151 test data
# event1  Task-152 test data
# event2  Task-153 test data
# event1  Task-154 test data
# event2  Task-155 test data
# event1  Task-156 test data
# event2  Task-157 test data
# event1  Task-158 test data
# event2  Task-159 test data
# event1  Task-160 test data
# event2  Task-161 test data
# event1  Task-162 test data
# event2  Task-163 test data
# event1  Task-164 test data
# event2  Task-165 test data
# event1  Task-166 test data
# event2  Task-167 test data
# event1  Task-168 test data
# event2  Task-169 test data
# event1  Task-170 test data
# event2  Task-171 test data
# event1  Task-172 test data
# event2  Task-173 test data
# event1  Task-174 test data
# event2  Task-175 test data
# event1  Task-176 test data
# event2  Task-177 test data
# event1  Task-178 test data
# event2  Task-179 test data
# event1  Task-180 test data
# event2  Task-181 test data
# event1  Task-182 test data
# event2  Task-183 test data
# event1  Task-184 test data
# event2  Task-185 test data
# event1  Task-186 test data
# event2  Task-187 test data
# event1  Task-188 test data
# event2  Task-189 test data
# event1  Task-190 test data
# event2  Task-191 test data
# event1  Task-192 test data
# event2  Task-193 test data
# event1  Task-194 test data
# event2  Task-195 test data
# event1  Task-196 test data
# event2  Task-197 test data
# event1  Task-198 test data
# event2  Task-199 test data
# event1  Task-200 test data
# event2  Task-201 test data
# event1  Task-202 test data
# event2  Task-203 test data
# event1  Task-204 test data
# event2  Task-205 test data
# event1  Task-206 test data
# event2  Task-207 test data
# event1  Task-208 test data
# event2  Task-209 test data
# event1  Task-210 test data
# event2  Task-211 test data
# event1  Task-212 test data
# event2  Task-213 test data
# event1  Task-214 test data
# event2  Task-215 test data
# event1  Task-216 test data
# event2  Task-217 test data
# event1  Task-218 test data
# event2  Task-219 test data
# event1  Task-220 test data
# event2  Task-221 test data

# %%
object_proxy.push_events()

# %%
object_proxy.unsubscribe_event("test_event")

# %%
for i in range(5):
    print(object_proxy.read_property("db_init_int_prop"), i)
# Out:
# 1 0
# 1 1
# 1 2
# 1 3
# 1 4

# %%
object_proxy.read_property("db_init_int_prop")
# Out:
# 1

# %%
object_proxy.set_non_remote_number_prop(15)
object_proxy.get_non_remote_number_prop()
# Out:
# 15

# %%
object_proxy.get_transports()
# Out:
# ['INPROC', 'IPC']

# %%
# object_proxy.get_serialized_data()
object_proxy_zmq.get_serialized_data()
# Out:
# b'foobar'

# %%
val, binary_val = object_proxy_zmq.get_mixed_content_data()
print(val)
print(binary_val)
# Out:
# foobar
# b'foobar'
